# %% [markdown]
# ## **Install Protobuf**

# %%
# %%capture
# !apt-get install autoconf automake libtool curl make g++ unzip
# !git clone https://github.com/protocolbuffers/protobuf.git
# %cd protobuf
# !git submodule update --init --recursive
# !./autogen.sh
# !./configure
# !make -j8
# !make check
# !sudo make install
# !sudo ldconfig 
# %cd ..

# %% [markdown]
# ## **Downloading the Files**

# %%
import shutil
import os 
# %cd /content/
if os.path.isdir('/content/HP3-CNN-Inferencing'):
  shutil.rmtree('/content/HP3-CNN-Inferencing')
# Out:
# /content

# %%
import os
from getpass import getpass
import urllib

user = input('User name: ')
password = getpass('Password: ')
password = urllib.parse.quote(password) # your password is converted into url format

cmd_string = 'git clone https://{0}:{1}@github.com/prajwal1210/HP3-CNN-Inferencing.git'.format(user, password)

os.system(cmd_string)
cmd_string, password = "", "" # removing the password from the variable
# Out:
# User name: prajwal1210
# Password: ··········

# %%
# %cd /content/HP3-CNN-Inferencing
# !ls
# Out:
# /content/HP3-CNN-Inferencing
# ConvertToSpecification.py  kernels	      profiling  README.md
# forward			   pretrained-models  proto

# %% [markdown]
# ## **Compiling Proto and Downloading the Pretrained Models and save them in protobuf format**

# %%
# %cd proto
# !protoc -I=. --cpp_out=. ./network.proto
# %cd ..
# Out:
# /content/HP3-CNN-Inferencing/proto
# /content/HP3-CNN-Inferencing

# %%
# !python ConvertToSpecification.py
# Out:
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/checkpoints/vgg19-dcbb9e9d.pth
# 100% 548M/548M [00:27<00:00, 21.0MB/s]
# Downloading: "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth" to /root/.cache/torch/checkpoints/alexnet-owt-4df8aa71.pth
# 100% 233M/233M [00:06<00:00, 37.5MB/s]

# %%
# %%capture
# %cd forward/data
# !unzip MiniImageNet.zip
# %cd ../../

# %% [markdown]
# ## **Forward Test**

# %% [markdown]
# #### **Single Image Test**

# %%
# %cd /content/HP3-CNN-Inferencing/forward/cnn_forward_test/
# !ls
# Out:
# /content/HP3-CNN-Inferencing/forward/cnn_forward_test
# cnn_forward_test.cc  cnn_forward_test.py  Makefile

# %%
# !make
# Out:
# nvcc -I /content/HP3-CNN-Inferencing -L /usr/local/cuda-10.1/man/man7/libcublas.so.7  -std=c++14 cnn_forward_test.cc /content/HP3-CNN-Inferencing/forward/operations.cc /content/HP3-CNN-Inferencing/forward/cnn_forward.cc /content/HP3-CNN-Inferencing/forward/data_util.cc /content/HP3-CNN-Inferencing/proto/translator.cc /content/HP3-CNN-Inferencing/proto/network.pb.cc /content/HP3-CNN-Inferencing/kernels/FFT/fft_fast.cu /content/HP3-CNN-Inferencing/kernels/Direct/direct_conv.cu /content/HP3-CNN-Inferencing/kernels/winograd/winograd_fast.cu /content/HP3-CNN-Inferencing/kernels/im2col/im2col.cu -I/usr/include/opencv -lopencv_shape -lopencv_stitching -lopencv_superres -lopencv_videostab -lopencv_aruco -lopencv_bgsegm -lopencv_bioinspired -lopencv_ccalib -lopencv_datasets -lopencv_dpm -lopencv_face -lopencv_freetype -lopencv_fuzzy -lopencv_hdf -lopencv_line_descriptor -lopencv_optflow -lopencv_video -lopencv_plot -lopencv_reg -lopencv_saliency -lopencv_stereo -lopencv_structured_light -lopencv_phase_unwrapping -lopencv_rgbd -lopencv_viz -lopencv_surface_matching -lopencv_text -lopencv_ximgproc -lopencv_calib3d -lopencv_features2d -lopencv_flann -lopencv_xobjdetect -lopencv_objdetect -lopencv_ml -lopencv_xphoto -lopencv_highgui -lopencv_videoio -lopencv_imgcodecs -lopencv_photo -lopencv_imgproc -lopencv_core -L/usr/local/lib -lprotobuf  -lcudnn -lcublas -lcufft -arch=sm_35 -rdc=true -O3 -o test

# %%
# !make run_direct
# Out:
# ./test "/content/HP3-CNN-Inferencing/pretrained-models/vgg19.pb" "DIRECT" 1>/dev/null
# tcmalloc: large alloc 1073750016 bytes == 0x5577c6608000 @  0x7f8cf1705887 0x7f8cc9e9b07d 0x7f8cc9e8eca8 0x7f8cc9e994ab 0x7f8cc9e224e5 0x7f8cc9e89518 0x557783c38ad3 0x557783c3242f 0x7f8cc978eb97 0x557783c32b3a
# python cnn_forward_test.py vgg
# Average difference between two values of the output layer - 0.000001
#
# ./test "/content/HP3-CNN-Inferencing/pretrained-models/alexnet.pb" "DIRECT" 1>/dev/null
# python cnn_forward_test.py alex
# Average difference between two values of the output layer - 0.000001

# %%
# !make run_im2col
# Out:
# ./test "/content/HP3-CNN-Inferencing/pretrained-models/vgg19.pb" "IM2COL" 1>/dev/null
# tcmalloc: large alloc 1073750016 bytes == 0x56083381a000 @  0x7ff554272887 0x7ff52ca0807d 0x7ff52c9fbca8 0x7ff52ca064ab 0x7ff52c98f4e5 0x7ff52c9f6518 0x5607f1a86ad3 0x5607f1a8042f 0x7ff52c2fbb97 0x5607f1a80b3a
# python cnn_forward_test.py vgg
# Average difference between two values of the output layer - 0.000001
#
# ./test "/content/HP3-CNN-Inferencing/pretrained-models/alexnet.pb" "IM2COL" 1>/dev/null
# python cnn_forward_test.py alex
# Average difference between two values of the output layer - 0.000001

# %%
# !make run_fft
# Out:
# ./test "/content/HP3-CNN-Inferencing/pretrained-models/vgg19.pb" "FFT" 1>/dev/null
# tcmalloc: large alloc 1073750016 bytes == 0x564d10c80000 @  0x7fcc8c755887 0x7fcc64eeb07d 0x7fcc64edeca8 0x7fcc64ee94ab 0x7fcc64e724e5 0x7fcc64ed9518 0x564ccdb3fad3 0x564ccdb3942f 0x7fcc647deb97 0x564ccdb39b3a
# python cnn_forward_test.py vgg
# Average difference between two values of the output layer - 0.000004
#
# ./test "/content/HP3-CNN-Inferencing/pretrained-models/alexnet.pb" "FFT" 1>/dev/null
# python cnn_forward_test.py alex
# Average difference between two values of the output layer - 0.000002

# %%
# !make run_winograd
# Out:
# ./test "/content/HP3-CNN-Inferencing/pretrained-models/vgg19.pb" "WINOGRAD" 1>/dev/null
# tcmalloc: large alloc 1073750016 bytes == 0x555d215a0000 @  0x7fbd817fb887 0x7fbd59f9107d 0x7fbd59f84ca8 0x7fbd59f8f4ab 0x7fbd59f184e5 0x7fbd59f7f518 0x555cdea09ad3 0x555cdea0342f 0x7fbd59884b97 0x555cdea03b3a
# python cnn_forward_test.py vgg
# Average difference between two values of the output layer - 0.000001

# %% [markdown]
# #### **Batch Test**

# %%
# %cd /content/HP3-CNN-Inferencing/forward/batch_test/
# Out:
# /content/HP3-CNN-Inferencing/forward/batch_test

# %%
# !make
# Out:
# nvcc -I /content/HP3-CNN-Inferencing -L /usr/local/cuda-10.1/man/man7/libcublas.so.7  -std=c++14 batch_test.cc /content/HP3-CNN-Inferencing/forward/operations.cc /content/HP3-CNN-Inferencing/forward/cnn_forward.cc /content/HP3-CNN-Inferencing/forward/data_util.cc /content/HP3-CNN-Inferencing/proto/translator.cc /content/HP3-CNN-Inferencing/proto/network.pb.cc /content/HP3-CNN-Inferencing/kernels/FFT/fft_fast.cu /content/HP3-CNN-Inferencing/kernels/Direct/direct_conv.cu /content/HP3-CNN-Inferencing/kernels/winograd/winograd_fast.cu /content/HP3-CNN-Inferencing/kernels/im2col/im2col.cu -I/usr/include/opencv -lopencv_shape -lopencv_stitching -lopencv_superres -lopencv_videostab -lopencv_aruco -lopencv_bgsegm -lopencv_bioinspired -lopencv_ccalib -lopencv_datasets -lopencv_dpm -lopencv_face -lopencv_freetype -lopencv_fuzzy -lopencv_hdf -lopencv_line_descriptor -lopencv_optflow -lopencv_video -lopencv_plot -lopencv_reg -lopencv_saliency -lopencv_stereo -lopencv_structured_light -lopencv_phase_unwrapping -lopencv_rgbd -lopencv_viz -lopencv_surface_matching -lopencv_text -lopencv_ximgproc -lopencv_calib3d -lopencv_features2d -lopencv_flann -lopencv_xobjdetect -lopencv_objdetect -lopencv_ml -lopencv_xphoto -lopencv_highgui -lopencv_videoio -lopencv_imgcodecs -lopencv_photo -lopencv_imgproc -lopencv_core -L/usr/local/lib -lprotobuf  -lcudnn -lcublas -lcufft -arch=sm_35 -rdc=true -O3 -o test

# %%
# !make run_direct
# Out:
# ./test "/content/HP3-CNN-Inferencing/pretrained-models/vgg19.pb" "DIRECT" 1>/dev/null
# tcmalloc: large alloc 1073750016 bytes == 0x564a36d4a000 @  0x7fb4a63e8887 0x7fb47eb7e07d 0x7fb47eb71ca8 0x7fb47eb7c4ab 0x7fb47eb054e5 0x7fb47eb6c518 0x5649f5162bb3 0x5649f515c42f 0x7fb47e471b97 0x5649f515cc1a
# python batch_test.py vgg
# Average difference between two values of the output layer - 0.000001
#
# ./test "/content/HP3-CNN-Inferencing/pretrained-models/alexnet.pb" "DIRECT" 1>/dev/null
# python batch_test.py alex
# Average difference between two values of the output layer - 0.000001

# %%
# !make run_im2col
# Out:
# ./test "/content/HP3-CNN-Inferencing/pretrained-models/vgg19.pb" "IM2COL" 1>/dev/null
# tcmalloc: large alloc 1073750016 bytes == 0x55af4358c000 @  0x7f3c4a91e887 0x7f3c230b407d 0x7f3c230a7ca8 0x7f3c230b24ab 0x7f3c2303b4e5 0x7f3c230a2518 0x55af01dbdbb3 0x55af01db742f 0x7f3c229a7b97 0x55af01db7c1a
# python batch_test.py vgg
# Average difference between two values of the output layer - 0.000001
#
# ./test "/content/HP3-CNN-Inferencing/pretrained-models/alexnet.pb" "IM2COL" 1>/dev/null
# python batch_test.py alex
# Average difference between two values of the output layer - 0.000001

# %%
# !make run_fft
# Out:
# ./test "/content/HP3-CNN-Inferencing/pretrained-models/vgg19.pb" "FFT" 1>/dev/null
# tcmalloc: large alloc 1073750016 bytes == 0x55b5db632000 @  0x7f6192d35887 0x7f616b4cb07d 0x7f616b4beca8 0x7f616b4c94ab 0x7f616b4524e5 0x7f616b4b9518 0x55b598ff7bb3 0x55b598ff142f 0x7f616adbeb97 0x55b598ff1c1a
# python batch_test.py vgg
# Average difference between two values of the output layer - 0.000004
#
# ./test "/content/HP3-CNN-Inferencing/pretrained-models/alexnet.pb" "FFT" 1>/dev/null
# python batch_test.py alex
# Average difference between two values of the output layer - 0.000002

# %%
# !make run_winograd
# Out:
# ./test "/content/HP3-CNN-Inferencing/pretrained-models/vgg19.pb" "WINOGRAD" 1>/dev/null
# tcmalloc: large alloc 1073750016 bytes == 0x562d645b2000 @  0x7fbc1703e887 0x7fbbef7d407d 0x7fbbef7c7ca8 0x7fbbef7d24ab 0x7fbbef75b4e5 0x7fbbef7c2518 0x562d21821bb3 0x562d2181b42f 0x7fbbef0c7b97 0x562d2181bc1a
# python batch_test.py vgg
# Average difference between two values of the output layer - 0.000001

# %% [markdown]
# ## **Profiling**

# %%
# %cd /content/HP3-CNN-Inferencing/profiling
# Out:
# /content/HP3-CNN-Inferencing/profiling

# %%
# !make
# Out:
# nvcc -I /content/HP3-CNN-Inferencing -L /usr/local/cuda-10.1/man/man7/libcublas.so.7  -std=c++14 profiler.cc /content/HP3-CNN-Inferencing/forward/operations.cc /content/HP3-CNN-Inferencing/forward/cnn_forward.cc /content/HP3-CNN-Inferencing/forward/data_util.cc /content/HP3-CNN-Inferencing/proto/translator.cc /content/HP3-CNN-Inferencing/proto/network.pb.cc /content/HP3-CNN-Inferencing/kernels/FFT/fft_fast.cu /content/HP3-CNN-Inferencing/kernels/Direct/direct_conv.cu /content/HP3-CNN-Inferencing/kernels/winograd/winograd_fast.cu /content/HP3-CNN-Inferencing/kernels/im2col/im2col.cu -I/usr/include/opencv -lopencv_shape -lopencv_stitching -lopencv_superres -lopencv_videostab -lopencv_aruco -lopencv_bgsegm -lopencv_bioinspired -lopencv_ccalib -lopencv_datasets -lopencv_dpm -lopencv_face -lopencv_freetype -lopencv_fuzzy -lopencv_hdf -lopencv_line_descriptor -lopencv_optflow -lopencv_video -lopencv_plot -lopencv_reg -lopencv_saliency -lopencv_stereo -lopencv_structured_light -lopencv_phase_unwrapping -lopencv_rgbd -lopencv_viz -lopencv_surface_matching -lopencv_text -lopencv_ximgproc -lopencv_calib3d -lopencv_features2d -lopencv_flann -lopencv_xobjdetect -lopencv_objdetect -lopencv_ml -lopencv_xphoto -lopencv_highgui -lopencv_videoio -lopencv_imgcodecs -lopencv_photo -lopencv_imgproc -lopencv_core -L/usr/local/lib -lprotobuf  -lcudnn -lcublas -lcufft -arch=sm_35 -rdc=true -O3 -o test

# %%
# !make run_vgg
# Out:
# rm -f logVGG.txt
# ./test "VGG" "/content/HP3-CNN-Inferencing/pretrained-models/vgg19.pb" "DIRECT"
# tcmalloc: large alloc 1073750016 bytes == 0x55a5227f2000 @  0x7f0d69c93887 0x7f0d4242907d 0x7f0d4241cca8 0x7f0d424274ab 0x7f0d423b04e5 0x7f0d42417518 0x55a4df57eea3 0x55a4df57785f 0x7f0d4197eb97 0x55a4df577fba
# FOR THE ALGORITHM : DIRECT
# ../forward/data/MiniImageNet/ImageLists.txt
# Running for Batchsize - 1
# Processing the Layer Type : CONV(64, 3, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 64, 256, 256)
# USING DIRECT CONVOLUTION
# Input - ( 1, 3, 256, 256 )
# TIME ELAPSED - 17.6247 = 5.64346 + 0.382944
# Output - ( 1, 64, 256, 256 )
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 64, 256, 256)
# Input - ( 1, 64, 256, 256 )
# Output - ( 1, 64, 256, 256 )
# Processing the Layer Type : CONV(64, 64, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 64, 256, 256)
# USING DIRECT CONVOLUTION
# Input - ( 1, 64, 256, 256 )
# TIME ELAPSED - 142.394 = 107.574 + 7.93094
# Output - ( 1, 64, 256, 256 )
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 64, 256, 256)
# Input - ( 1, 64, 256, 256 )
# Output - ( 1, 64, 256, 256 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (1, 64, 128, 128)
# Input - ( 1, 64, 256, 256 )
# Output - ( 1, 64, 128, 128 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(128, 64, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 128, 128, 128)
# USING DIRECT CONVOLUTION
# Input - ( 1, 64, 128, 128 )
# TIME ELAPSED - 61.7687 = 49.1595 + 1.85069
# Output - ( 1, 128, 128, 128 )
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 128, 128, 128)
# Input - ( 1, 128, 128, 128 )
# Output - ( 1, 128, 128, 128 )
# Processing the Layer Type : CONV(128, 128, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 128, 128, 128)
# USING DIRECT CONVOLUTION
# Input - ( 1, 128, 128, 128 )
# TIME ELAPSED - 112.488 = 97.5901 + 3.68982
# Output - ( 1, 128, 128, 128 )
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 128, 128, 128)
# Input - ( 1, 128, 128, 128 )
# Output - ( 1, 128, 128, 128 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (1, 128, 64, 64)
# Input - ( 1, 128, 128, 128 )
# Output - ( 1, 128, 64, 64 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(256, 128, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 256, 64, 64)
# USING DIRECT CONVOLUTION
# Input - ( 1, 128, 64, 64 )
# TIME ELAPSED - 53.997 = 48.5048 + 0.94624
# Output - ( 1, 256, 64, 64 )
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 256, 64, 64)
# Input - ( 1, 256, 64, 64 )
# Output - ( 1, 256, 64, 64 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 256, 64, 64)
# USING DIRECT CONVOLUTION
# Input - ( 1, 256, 64, 64 )
# TIME ELAPSED - 106.333 = 96.8115 + 1.88163
# Output - ( 1, 256, 64, 64 )
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 256, 64, 64)
# Input - ( 1, 256, 64, 64 )
# Output - ( 1, 256, 64, 64 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 256, 64, 64)
# USING DIRECT CONVOLUTION
# Input - ( 1, 256, 64, 64 )
# TIME ELAPSED - 105.565 = 96.8114 + 1.88605
# Output - ( 1, 256, 64, 64 )
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 256, 64, 64)
# Input - ( 1, 256, 64, 64 )
# Output - ( 1, 256, 64, 64 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 256, 64, 64)
# USING DIRECT CONVOLUTION
# Input - ( 1, 256, 64, 64 )
# TIME ELAPSED - 105.976 = 96.805 + 1.88256
# Output - ( 1, 256, 64, 64 )
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 256, 64, 64)
# Input - ( 1, 256, 64, 64 )
# Output - ( 1, 256, 64, 64 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (1, 256, 32, 32)
# Input - ( 1, 256, 64, 64 )
# Output - ( 1, 256, 32, 32 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(512, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 512, 32, 32)
# USING DIRECT CONVOLUTION
# Input - ( 1, 256, 32, 32 )
# TIME ELAPSED - 60.998 = 56.8724 + 0.504864
# Output - ( 1, 512, 32, 32 )
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 512, 32, 32)
# Input - ( 1, 512, 32, 32 )
# Output - ( 1, 512, 32, 32 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 512, 32, 32)
# USING DIRECT CONVOLUTION
# Input - ( 1, 512, 32, 32 )
# TIME ELAPSED - 114.098 = 106.955 + 1.00467
# Output - ( 1, 512, 32, 32 )
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 512, 32, 32)
# Input - ( 1, 512, 32, 32 )
# Output - ( 1, 512, 32, 32 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 512, 32, 32)
# USING DIRECT CONVOLUTION
# Input - ( 1, 512, 32, 32 )
# TIME ELAPSED - 114.117 = 106.982 + 1.00294
# Output - ( 1, 512, 32, 32 )
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 512, 32, 32)
# Input - ( 1, 512, 32, 32 )
# Output - ( 1, 512, 32, 32 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 512, 32, 32)
# USING DIRECT CONVOLUTION
# Input - ( 1, 512, 32, 32 )
# TIME ELAPSED - 114.029 = 106.965 + 1.0063
# Output - ( 1, 512, 32, 32 )
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 512, 32, 32)
# Input - ( 1, 512, 32, 32 )
# Output - ( 1, 512, 32, 32 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (1, 512, 16, 16)
# Input - ( 1, 512, 32, 32 )
# Output - ( 1, 512, 16, 16 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 512, 16, 16)
# USING DIRECT CONVOLUTION
# Input - ( 1, 512, 16, 16 )
# TIME ELAPSED - 30.9638 = 27.361 + 0.290144
# Output - ( 1, 512, 16, 16 )
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 512, 16, 16)
# Input - ( 1, 512, 16, 16 )
# Output - ( 1, 512, 16, 16 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 512, 16, 16)
# USING DIRECT CONVOLUTION
# Input - ( 1, 512, 16, 16 )
# TIME ELAPSED - 31.0994 = 27.352 + 0.28464
# Output - ( 1, 512, 16, 16 )
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 512, 16, 16)
# Input - ( 1, 512, 16, 16 )
# Output - ( 1, 512, 16, 16 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 512, 16, 16)
# USING DIRECT CONVOLUTION
# Input - ( 1, 512, 16, 16 )
# TIME ELAPSED - 31.1739 = 27.357 + 0.29088
# Output - ( 1, 512, 16, 16 )
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 512, 16, 16)
# Input - ( 1, 512, 16, 16 )
# Output - ( 1, 512, 16, 16 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 512, 16, 16)
# USING DIRECT CONVOLUTION
# Input - ( 1, 512, 16, 16 )
# TIME ELAPSED - 31.0881 = 27.3904 + 0.284576
# Output - ( 1, 512, 16, 16 )
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 512, 16, 16)
# Input - ( 1, 512, 16, 16 )
# Output - ( 1, 512, 16, 16 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (1, 512, 8, 8)
# Input - ( 1, 512, 16, 16 )
# Output - ( 1, 512, 8, 8 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : ADAPTIVE_POOL(AVG, kernel_size = (2, 2), stride = (1 ,1), padding = (0 ,0)) --> (1, 512, 7, 7)
# Input - ( 1, 512, 8, 8 )
# Output - ( 1, 512, 7, 7 )
# Kernel Size - ( 2, 2 )
# Stride - ( 1, 1 )
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 25088) --> (1, 4096, 1, 1)
# Input - ( 1, 25088, 1, 1 )
# Output - ( 1, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 4096, 1, 1)
# Input - ( 1, 4096, 1, 1 )
# Output - ( 1, 4096, 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 4096) --> (1, 4096, 1, 1)
# Input - ( 1, 4096, 1, 1 )
# Output - ( 1, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 4096, 1, 1)
# Input - ( 1, 4096, 1, 1 )
# Output - ( 1, 4096, 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 1000, in_nodes = 4096) --> (1, 1000, 1, 1)
# Input - ( 1, 4096, 1, 1 )
# Output - ( 1, 1000, 1, 1 )
# ../forward/data/MiniImageNet/ImageLists.txt
# Running for Batchsize - 2
# Processing the Layer Type : CONV(64, 3, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 64, 256, 256)
# USING DIRECT CONVOLUTION
# Input - ( 2, 3, 256, 256 )
# TIME ELAPSED - 24.7812 = 10.1944 + 0.687712
# Output - ( 2, 64, 256, 256 )
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 64, 256, 256)
# Input - ( 2, 64, 256, 256 )
# Output - ( 2, 64, 256, 256 )
# Processing the Layer Type : CONV(64, 64, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 64, 256, 256)
# USING DIRECT CONVOLUTION
# Input - ( 2, 64, 256, 256 )
# TIME ELAPSED - 247.665 = 194.593 + 14.3398
# Output - ( 2, 64, 256, 256 )
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 64, 256, 256)
# Input - ( 2, 64, 256, 256 )
# Output - ( 2, 64, 256, 256 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (2, 64, 128, 128)
# Input - ( 2, 64, 256, 256 )
# Output - ( 2, 64, 128, 128 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(128, 64, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 128, 128, 128)
# USING DIRECT CONVOLUTION
# Input - ( 2, 64, 128, 128 )
# TIME ELAPSED - 114.26 = 97.1544 + 3.65978
# Output - ( 2, 128, 128, 128 )
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 128, 128, 128)
# Input - ( 2, 128, 128, 128 )
# Output - ( 2, 128, 128, 128 )
# Processing the Layer Type : CONV(128, 128, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 128, 128, 128)
# USING DIRECT CONVOLUTION
# Input - ( 2, 128, 128, 128 )
# TIME ELAPSED - 221.959 = 193.771 + 7.29206
# Output - ( 2, 128, 128, 128 )
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 128, 128, 128)
# Input - ( 2, 128, 128, 128 )
# Output - ( 2, 128, 128, 128 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (2, 128, 64, 64)
# Input - ( 2, 128, 128, 128 )
# Output - ( 2, 128, 64, 64 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(256, 128, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 256, 64, 64)
# USING DIRECT CONVOLUTION
# Input - ( 2, 128, 64, 64 )
# TIME ELAPSED - 106.882 = 96.834 + 1.89235
# Output - ( 2, 256, 64, 64 )
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 256, 64, 64)
# Input - ( 2, 256, 64, 64 )
# Output - ( 2, 256, 64, 64 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 256, 64, 64)
# USING DIRECT CONVOLUTION
# Input - ( 2, 256, 64, 64 )
# TIME ELAPSED - 209.955 = 193.45 + 3.76806
# Output - ( 2, 256, 64, 64 )
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 256, 64, 64)
# Input - ( 2, 256, 64, 64 )
# Output - ( 2, 256, 64, 64 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 256, 64, 64)
# USING DIRECT CONVOLUTION
# Input - ( 2, 256, 64, 64 )
# TIME ELAPSED - 209.582 = 193.437 + 3.76483
# Output - ( 2, 256, 64, 64 )
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 256, 64, 64)
# Input - ( 2, 256, 64, 64 )
# Output - ( 2, 256, 64, 64 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 256, 64, 64)
# USING DIRECT CONVOLUTION
# Input - ( 2, 256, 64, 64 )
# TIME ELAPSED - 209.141 = 193.43 + 3.77168
# Output - ( 2, 256, 64, 64 )
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 256, 64, 64)
# Input - ( 2, 256, 64, 64 )
# Output - ( 2, 256, 64, 64 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (2, 256, 32, 32)
# Input - ( 2, 256, 64, 64 )
# Output - ( 2, 256, 32, 32 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(512, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 512, 32, 32)
# USING DIRECT CONVOLUTION
# Input - ( 2, 256, 32, 32 )
# TIME ELAPSED - 117.035 = 109.916 + 1.01578
# Output - ( 2, 512, 32, 32 )
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 512, 32, 32)
# Input - ( 2, 512, 32, 32 )
# Output - ( 2, 512, 32, 32 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 512, 32, 32)
# USING DIRECT CONVOLUTION
# Input - ( 2, 512, 32, 32 )
# TIME ELAPSED - 223.861 = 213.046 + 2.0128
# Output - ( 2, 512, 32, 32 )
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 512, 32, 32)
# Input - ( 2, 512, 32, 32 )
# Output - ( 2, 512, 32, 32 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 512, 32, 32)
# USING DIRECT CONVOLUTION
# Input - ( 2, 512, 32, 32 )
# TIME ELAPSED - 223.85 = 213.016 + 2.00378
# Output - ( 2, 512, 32, 32 )
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 512, 32, 32)
# Input - ( 2, 512, 32, 32 )
# Output - ( 2, 512, 32, 32 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 512, 32, 32)
# USING DIRECT CONVOLUTION
# Input - ( 2, 512, 32, 32 )
# TIME ELAPSED - 224.154 = 213.047 + 2.02349
# Output - ( 2, 512, 32, 32 )
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 512, 32, 32)
# Input - ( 2, 512, 32, 32 )
# Output - ( 2, 512, 32, 32 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (2, 512, 16, 16)
# Input - ( 2, 512, 32, 32 )
# Output - ( 2, 512, 16, 16 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 512, 16, 16)
# USING DIRECT CONVOLUTION
# Input - ( 2, 512, 16, 16 )
# TIME ELAPSED - 58.4601 = 53.6455 + 0.57568
# Output - ( 2, 512, 16, 16 )
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 512, 16, 16)
# Input - ( 2, 512, 16, 16 )
# Output - ( 2, 512, 16, 16 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 512, 16, 16)
# USING DIRECT CONVOLUTION
# Input - ( 2, 512, 16, 16 )
# TIME ELAPSED - 58.5102 = 53.6509 + 0.578688
# Output - ( 2, 512, 16, 16 )
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 512, 16, 16)
# Input - ( 2, 512, 16, 16 )
# Output - ( 2, 512, 16, 16 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 512, 16, 16)
# USING DIRECT CONVOLUTION
# Input - ( 2, 512, 16, 16 )
# TIME ELAPSED - 58.6931 = 53.701 + 0.575904
# Output - ( 2, 512, 16, 16 )
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 512, 16, 16)
# Input - ( 2, 512, 16, 16 )
# Output - ( 2, 512, 16, 16 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 512, 16, 16)
# USING DIRECT CONVOLUTION
# Input - ( 2, 512, 16, 16 )
# TIME ELAPSED - 58.5415 = 53.6378 + 0.577664
# Output - ( 2, 512, 16, 16 )
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 512, 16, 16)
# Input - ( 2, 512, 16, 16 )
# Output - ( 2, 512, 16, 16 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (2, 512, 8, 8)
# Input - ( 2, 512, 16, 16 )
# Output - ( 2, 512, 8, 8 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : ADAPTIVE_POOL(AVG, kernel_size = (2, 2), stride = (1 ,1), padding = (0 ,0)) --> (2, 512, 7, 7)
# Input - ( 2, 512, 8, 8 )
# Output - ( 2, 512, 7, 7 )
# Kernel Size - ( 2, 2 )
# Stride - ( 1, 1 )
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 25088) --> (2, 4096, 1, 1)
# Input - ( 2, 25088, 1, 1 )
# Output - ( 2, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 4096, 1, 1)
# Input - ( 2, 4096, 1, 1 )
# Output - ( 2, 4096, 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 4096) --> (2, 4096, 1, 1)
# Input - ( 2, 4096, 1, 1 )
# Output - ( 2, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 4096, 1, 1)
# Input - ( 2, 4096, 1, 1 )
# Output - ( 2, 4096, 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 1000, in_nodes = 4096) --> (2, 1000, 1, 1)
# Input - ( 2, 4096, 1, 1 )
# Output - ( 2, 1000, 1, 1 )
# ../forward/data/MiniImageNet/ImageLists.txt
# Running for Batchsize - 4
# Processing the Layer Type : CONV(64, 3, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 64, 256, 256)
# USING DIRECT CONVOLUTION
# Input - ( 4, 3, 256, 256 )
# TIME ELAPSED - 47.14 = 20.3491 + 1.38006
# Output - ( 4, 64, 256, 256 )
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 64, 256, 256)
# Input - ( 4, 64, 256, 256 )
# Output - ( 4, 64, 256, 256 )
# Processing the Layer Type : CONV(64, 64, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 64, 256, 256)
# USING DIRECT CONVOLUTION
# Input - ( 4, 64, 256, 256 )
# TIME ELAPSED - 493.841 = 388.938 + 28.6798
# Output - ( 4, 64, 256, 256 )
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 64, 256, 256)
# Input - ( 4, 64, 256, 256 )
# Output - ( 4, 64, 256, 256 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (4, 64, 128, 128)
# Input - ( 4, 64, 256, 256 )
# Output - ( 4, 64, 128, 128 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(128, 64, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 128, 128, 128)
# USING DIRECT CONVOLUTION
# Input - ( 4, 64, 128, 128 )
# TIME ELAPSED - 227.335 = 194.231 + 7.30995
# Output - ( 4, 128, 128, 128 )
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 128, 128, 128)
# Input - ( 4, 128, 128, 128 )
# Output - ( 4, 128, 128, 128 )
# Processing the Layer Type : CONV(128, 128, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 128, 128, 128)
# USING DIRECT CONVOLUTION
# Input - ( 4, 128, 128, 128 )
# TIME ELAPSED - 440.613 = 387.355 + 14.5846
# Output - ( 4, 128, 128, 128 )
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 128, 128, 128)
# Input - ( 4, 128, 128, 128 )
# Output - ( 4, 128, 128, 128 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (4, 128, 64, 64)
# Input - ( 4, 128, 128, 128 )
# Output - ( 4, 128, 64, 64 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(256, 128, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 256, 64, 64)
# USING DIRECT CONVOLUTION
# Input - ( 4, 128, 64, 64 )
# TIME ELAPSED - 212.995 = 193.567 + 3.79123
# Output - ( 4, 256, 64, 64 )
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 256, 64, 64)
# Input - ( 4, 256, 64, 64 )
# Output - ( 4, 256, 64, 64 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 256, 64, 64)
# USING DIRECT CONVOLUTION
# Input - ( 4, 256, 64, 64 )
# TIME ELAPSED - 416.614 = 387.466 + 7.53584
# Output - ( 4, 256, 64, 64 )
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 256, 64, 64)
# Input - ( 4, 256, 64, 64 )
# Output - ( 4, 256, 64, 64 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 256, 64, 64)
# USING DIRECT CONVOLUTION
# Input - ( 4, 256, 64, 64 )
# TIME ELAPSED - 416.705 = 387.481 + 7.53552
# Output - ( 4, 256, 64, 64 )
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 256, 64, 64)
# Input - ( 4, 256, 64, 64 )
# Output - ( 4, 256, 64, 64 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 256, 64, 64)
# USING DIRECT CONVOLUTION
# Input - ( 4, 256, 64, 64 )
# TIME ELAPSED - 417.089 = 387.466 + 7.544
# Output - ( 4, 256, 64, 64 )
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 256, 64, 64)
# Input - ( 4, 256, 64, 64 )
# Output - ( 4, 256, 64, 64 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (4, 256, 32, 32)
# Input - ( 4, 256, 64, 64 )
# Output - ( 4, 256, 32, 32 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(512, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 512, 32, 32)
# USING DIRECT CONVOLUTION
# Input - ( 4, 256, 32, 32 )
# TIME ELAPSED - 221.921 = 210.678 + 2.0289
# Output - ( 4, 512, 32, 32 )
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 512, 32, 32)
# Input - ( 4, 512, 32, 32 )
# Output - ( 4, 512, 32, 32 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 512, 32, 32)
# USING DIRECT CONVOLUTION
# Input - ( 4, 512, 32, 32 )
# TIME ELAPSED - 439.705 = 420.829 + 4.0199
# Output - ( 4, 512, 32, 32 )
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 512, 32, 32)
# Input - ( 4, 512, 32, 32 )
# Output - ( 4, 512, 32, 32 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 512, 32, 32)
# USING DIRECT CONVOLUTION
# Input - ( 4, 512, 32, 32 )
# TIME ELAPSED - 439.1 = 420.653 + 4.01363
# Output - ( 4, 512, 32, 32 )
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 512, 32, 32)
# Input - ( 4, 512, 32, 32 )
# Output - ( 4, 512, 32, 32 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 512, 32, 32)
# USING DIRECT CONVOLUTION
# Input - ( 4, 512, 32, 32 )
# TIME ELAPSED - 439.078 = 420.63 + 4.01331
# Output - ( 4, 512, 32, 32 )
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 512, 32, 32)
# Input - ( 4, 512, 32, 32 )
# Output - ( 4, 512, 32, 32 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (4, 512, 16, 16)
# Input - ( 4, 512, 32, 32 )
# Output - ( 4, 512, 16, 16 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 512, 16, 16)
# USING DIRECT CONVOLUTION
# Input - ( 4, 512, 16, 16 )
# TIME ELAPSED - 113.079 = 105.658 + 1.15968
# Output - ( 4, 512, 16, 16 )
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 512, 16, 16)
# Input - ( 4, 512, 16, 16 )
# Output - ( 4, 512, 16, 16 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 512, 16, 16)
# USING DIRECT CONVOLUTION
# Input - ( 4, 512, 16, 16 )
# TIME ELAPSED - 113.155 = 105.59 + 1.15542
# Output - ( 4, 512, 16, 16 )
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 512, 16, 16)
# Input - ( 4, 512, 16, 16 )
# Output - ( 4, 512, 16, 16 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 512, 16, 16)
# USING DIRECT CONVOLUTION
# Input - ( 4, 512, 16, 16 )
# TIME ELAPSED - 113.206 = 105.576 + 1.15917
# Output - ( 4, 512, 16, 16 )
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 512, 16, 16)
# Input - ( 4, 512, 16, 16 )
# Output - ( 4, 512, 16, 16 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 512, 16, 16)
# USING DIRECT CONVOLUTION
# Input - ( 4, 512, 16, 16 )
# TIME ELAPSED - 112.88 = 105.589 + 1.14979
# Output - ( 4, 512, 16, 16 )
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 512, 16, 16)
# Input - ( 4, 512, 16, 16 )
# Output - ( 4, 512, 16, 16 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (4, 512, 8, 8)
# Input - ( 4, 512, 16, 16 )
# Output - ( 4, 512, 8, 8 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : ADAPTIVE_POOL(AVG, kernel_size = (2, 2), stride = (1 ,1), padding = (0 ,0)) --> (4, 512, 7, 7)
# Input - ( 4, 512, 8, 8 )
# Output - ( 4, 512, 7, 7 )
# Kernel Size - ( 2, 2 )
# Stride - ( 1, 1 )
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 25088) --> (4, 4096, 1, 1)
# Input - ( 4, 25088, 1, 1 )
# Output - ( 4, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 4096, 1, 1)
# Input - ( 4, 4096, 1, 1 )
# Output - ( 4, 4096, 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 4096) --> (4, 4096, 1, 1)
# Input - ( 4, 4096, 1, 1 )
# Output - ( 4, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 4096, 1, 1)
# Input - ( 4, 4096, 1, 1 )
# Output - ( 4, 4096, 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 1000, in_nodes = 4096) --> (4, 1000, 1, 1)
# Input - ( 4, 4096, 1, 1 )
# Output - ( 4, 1000, 1, 1 )
# ../forward/data/MiniImageNet/ImageLists.txt
# Running for Batchsize - 8
# Processing the Layer Type : CONV(64, 3, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 64, 256, 256)
# USING DIRECT CONVOLUTION
# Input - ( 8, 3, 256, 256 )
# TIME ELAPSED - 89.983 = 40.6741 + 2.76307
# Output - ( 8, 64, 256, 256 )
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 64, 256, 256)
# Input - ( 8, 64, 256, 256 )
# Output - ( 8, 64, 256, 256 )
# Processing the Layer Type : CONV(64, 64, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 64, 256, 256)
# USING DIRECT CONVOLUTION
# Input - ( 8, 64, 256, 256 )
# TIME ELAPSED - 983.172 = 778.606 + 57.3689
# Output - ( 8, 64, 256, 256 )
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 64, 256, 256)
# Input - ( 8, 64, 256, 256 )
# Output - ( 8, 64, 256, 256 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (8, 64, 128, 128)
# Input - ( 8, 64, 256, 256 )
# Output - ( 8, 64, 128, 128 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(128, 64, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 128, 128, 128)
# USING DIRECT CONVOLUTION
# Input - ( 8, 64, 128, 128 )
# TIME ELAPSED - 453.22 = 388.383 + 14.6245
# Output - ( 8, 128, 128, 128 )
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 128, 128, 128)
# Input - ( 8, 128, 128, 128 )
# Output - ( 8, 128, 128, 128 )
# Processing the Layer Type : CONV(128, 128, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 128, 128, 128)
# USING DIRECT CONVOLUTION
# Input - ( 8, 128, 128, 128 )
# TIME ELAPSED - 886.33 = 775.252 + 29.1787
# Output - ( 8, 128, 128, 128 )
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 128, 128, 128)
# Input - ( 8, 128, 128, 128 )
# Output - ( 8, 128, 128, 128 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (8, 128, 64, 64)
# Input - ( 8, 128, 128, 128 )
# Output - ( 8, 128, 64, 64 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(256, 128, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 256, 64, 64)
# USING DIRECT CONVOLUTION
# Input - ( 8, 128, 64, 64 )
# TIME ELAPSED - 423.196 = 387.13 + 7.5801
# Output - ( 8, 256, 64, 64 )
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 256, 64, 64)
# Input - ( 8, 256, 64, 64 )
# Output - ( 8, 256, 64, 64 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 256, 64, 64)
# USING DIRECT CONVOLUTION
# Input - ( 8, 256, 64, 64 )
# TIME ELAPSED - 846.027 = 788.139 + 15.0666
# Output - ( 8, 256, 64, 64 )
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 256, 64, 64)
# Input - ( 8, 256, 64, 64 )
# Output - ( 8, 256, 64, 64 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 256, 64, 64)
# USING DIRECT CONVOLUTION
# Input - ( 8, 256, 64, 64 )
# TIME ELAPSED - 846.657 = 788.128 + 15.0728
# Output - ( 8, 256, 64, 64 )
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 256, 64, 64)
# Input - ( 8, 256, 64, 64 )
# Output - ( 8, 256, 64, 64 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 256, 64, 64)
# USING DIRECT CONVOLUTION
# Input - ( 8, 256, 64, 64 )
# TIME ELAPSED - 845.777 = 788.138 + 15.0704
# Output - ( 8, 256, 64, 64 )
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 256, 64, 64)
# Input - ( 8, 256, 64, 64 )
# Output - ( 8, 256, 64, 64 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (8, 256, 32, 32)
# Input - ( 8, 256, 64, 64 )
# Output - ( 8, 256, 32, 32 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(512, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 512, 32, 32)
# USING DIRECT CONVOLUTION
# Input - ( 8, 256, 32, 32 )
# TIME ELAPSED - 427.474 = 406.615 + 4.05715
# Output - ( 8, 512, 32, 32 )
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 512, 32, 32)
# Input - ( 8, 512, 32, 32 )
# Output - ( 8, 512, 32, 32 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 512, 32, 32)
# USING DIRECT CONVOLUTION
# Input - ( 8, 512, 32, 32 )
# TIME ELAPSED - 850.432 = 817.109 + 8.04099
# Output - ( 8, 512, 32, 32 )
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 512, 32, 32)
# Input - ( 8, 512, 32, 32 )
# Output - ( 8, 512, 32, 32 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 512, 32, 32)
# USING DIRECT CONVOLUTION
# Input - ( 8, 512, 32, 32 )
# TIME ELAPSED - 850.258 = 817.149 + 8.04803
# Output - ( 8, 512, 32, 32 )
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 512, 32, 32)
# Input - ( 8, 512, 32, 32 )
# Output - ( 8, 512, 32, 32 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 512, 32, 32)
# USING DIRECT CONVOLUTION
# Input - ( 8, 512, 32, 32 )
# TIME ELAPSED - 851.088 = 817.211 + 8.03203
# Output - ( 8, 512, 32, 32 )
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 512, 32, 32)
# Input - ( 8, 512, 32, 32 )
# Output - ( 8, 512, 32, 32 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (8, 512, 16, 16)
# Input - ( 8, 512, 32, 32 )
# Output - ( 8, 512, 16, 16 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 512, 16, 16)
# USING DIRECT CONVOLUTION
# Input - ( 8, 512, 16, 16 )
# TIME ELAPSED - 214.569 = 202.997 + 2.30816
# Output - ( 8, 512, 16, 16 )
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 512, 16, 16)
# Input - ( 8, 512, 16, 16 )
# Output - ( 8, 512, 16, 16 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 512, 16, 16)
# USING DIRECT CONVOLUTION
# Input - ( 8, 512, 16, 16 )
# TIME ELAPSED - 214.946 = 202.889 + 2.29734
# Output - ( 8, 512, 16, 16 )
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 512, 16, 16)
# Input - ( 8, 512, 16, 16 )
# Output - ( 8, 512, 16, 16 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 512, 16, 16)
# USING DIRECT CONVOLUTION
# Input - ( 8, 512, 16, 16 )
# TIME ELAPSED - 214.719 = 202.905 + 2.3095
# Output - ( 8, 512, 16, 16 )
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 512, 16, 16)
# Input - ( 8, 512, 16, 16 )
# Output - ( 8, 512, 16, 16 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 512, 16, 16)
# USING DIRECT CONVOLUTION
# Input - ( 8, 512, 16, 16 )
# TIME ELAPSED - 214.782 = 202.924 + 2.30659
# Output - ( 8, 512, 16, 16 )
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 512, 16, 16)
# Input - ( 8, 512, 16, 16 )
# Output - ( 8, 512, 16, 16 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (8, 512, 8, 8)
# Input - ( 8, 512, 16, 16 )
# Output - ( 8, 512, 8, 8 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : ADAPTIVE_POOL(AVG, kernel_size = (2, 2), stride = (1 ,1), padding = (0 ,0)) --> (8, 512, 7, 7)
# Input - ( 8, 512, 8, 8 )
# Output - ( 8, 512, 7, 7 )
# Kernel Size - ( 2, 2 )
# Stride - ( 1, 1 )
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 25088) --> (8, 4096, 1, 1)
# Input - ( 8, 25088, 1, 1 )
# Output - ( 8, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 4096, 1, 1)
# Input - ( 8, 4096, 1, 1 )
# Output - ( 8, 4096, 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 4096) --> (8, 4096, 1, 1)
# Input - ( 8, 4096, 1, 1 )
# Output - ( 8, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 4096, 1, 1)
# Input - ( 8, 4096, 1, 1 )
# Output - ( 8, 4096, 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 1000, in_nodes = 4096) --> (8, 1000, 1, 1)
# Input - ( 8, 4096, 1, 1 )
# Output - ( 8, 1000, 1, 1 )
# ./test "VGG" "/content/HP3-CNN-Inferencing/pretrained-models/vgg19.pb" "IM2COL"
# tcmalloc: large alloc 1073750016 bytes == 0x560550aea000 @  0x7f4356f74887 0x7f432f70a07d 0x7f432f6fdca8 0x7f432f7084ab 0x7f432f6914e5 0x7f432f6f8518 0x56050de19ea3 0x56050de1285f 0x7f432ec5fb97 0x56050de12fba
# FOR THE ALGORITHM : IM2COL
# ../forward/data/MiniImageNet/ImageLists.txt
# Running for Batchsize - 1
# Processing the Layer Type : CONV(64, 3, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 64, 256, 256)
# USING Im2Col CONVOLUTION
# Input - ( 1, 3, 256, 256 )
# Output - ( 1, 64, 256, 256 )
# TIME ELAPSED - 11.954 = 0.186912 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 64, 256, 256)
# Input - ( 1, 64, 256, 256 )
# Output - ( 1, 64, 256, 256 )
# Processing the Layer Type : CONV(64, 64, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 64, 256, 256)
# USING Im2Col CONVOLUTION
# Input - ( 1, 64, 256, 256 )
# Output - ( 1, 64, 256, 256 )
# TIME ELAPSED - 14.4251 = 1.24669 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 64, 256, 256)
# Input - ( 1, 64, 256, 256 )
# Output - ( 1, 64, 256, 256 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (1, 64, 128, 128)
# Input - ( 1, 64, 256, 256 )
# Output - ( 1, 64, 128, 128 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(128, 64, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 128, 128, 128)
# USING Im2Col CONVOLUTION
# Input - ( 1, 64, 128, 128 )
# Output - ( 1, 128, 128, 128 )
# TIME ELAPSED - 6.49581 = 0.592288 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 128, 128, 128)
# Input - ( 1, 128, 128, 128 )
# Output - ( 1, 128, 128, 128 )
# Processing the Layer Type : CONV(128, 128, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 128, 128, 128)
# USING Im2Col CONVOLUTION
# Input - ( 1, 128, 128, 128 )
# Output - ( 1, 128, 128, 128 )
# TIME ELAPSED - 9.34445 = 0.943776 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 128, 128, 128)
# Input - ( 1, 128, 128, 128 )
# Output - ( 1, 128, 128, 128 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (1, 128, 64, 64)
# Input - ( 1, 128, 128, 128 )
# Output - ( 1, 128, 64, 64 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(256, 128, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 256, 64, 64)
# USING Im2Col CONVOLUTION
# Input - ( 1, 128, 64, 64 )
# Output - ( 1, 256, 64, 64 )
# TIME ELAPSED - 4.05962 = 0.471872 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 256, 64, 64)
# Input - ( 1, 256, 64, 64 )
# Output - ( 1, 256, 64, 64 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 256, 64, 64)
# USING Im2Col CONVOLUTION
# Input - ( 1, 256, 64, 64 )
# Output - ( 1, 256, 64, 64 )
# TIME ELAPSED - 6.33635 = 0.826688 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 256, 64, 64)
# Input - ( 1, 256, 64, 64 )
# Output - ( 1, 256, 64, 64 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 256, 64, 64)
# USING Im2Col CONVOLUTION
# Input - ( 1, 256, 64, 64 )
# Output - ( 1, 256, 64, 64 )
# TIME ELAPSED - 6.10842 = 0.823072 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 256, 64, 64)
# Input - ( 1, 256, 64, 64 )
# Output - ( 1, 256, 64, 64 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 256, 64, 64)
# USING Im2Col CONVOLUTION
# Input - ( 1, 256, 64, 64 )
# Output - ( 1, 256, 64, 64 )
# TIME ELAPSED - 7.54906 = 0.82208 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 256, 64, 64)
# Input - ( 1, 256, 64, 64 )
# Output - ( 1, 256, 64, 64 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (1, 256, 32, 32)
# Input - ( 1, 256, 64, 64 )
# Output - ( 1, 256, 32, 32 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(512, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 512, 32, 32)
# USING Im2Col CONVOLUTION
# Input - ( 1, 256, 32, 32 )
# Output - ( 1, 512, 32, 32 )
# TIME ELAPSED - 3.82022 = 0.432384 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 512, 32, 32)
# Input - ( 1, 512, 32, 32 )
# Output - ( 1, 512, 32, 32 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 512, 32, 32)
# USING Im2Col CONVOLUTION
# Input - ( 1, 512, 32, 32 )
# Output - ( 1, 512, 32, 32 )
# TIME ELAPSED - 6.12179 = 0.7664 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 512, 32, 32)
# Input - ( 1, 512, 32, 32 )
# Output - ( 1, 512, 32, 32 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 512, 32, 32)
# USING Im2Col CONVOLUTION
# Input - ( 1, 512, 32, 32 )
# Output - ( 1, 512, 32, 32 )
# TIME ELAPSED - 6.09174 = 0.768256 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 512, 32, 32)
# Input - ( 1, 512, 32, 32 )
# Output - ( 1, 512, 32, 32 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 512, 32, 32)
# USING Im2Col CONVOLUTION
# Input - ( 1, 512, 32, 32 )
# Output - ( 1, 512, 32, 32 )
# TIME ELAPSED - 6.60336 = 0.818048 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 512, 32, 32)
# Input - ( 1, 512, 32, 32 )
# Output - ( 1, 512, 32, 32 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (1, 512, 16, 16)
# Input - ( 1, 512, 32, 32 )
# Output - ( 1, 512, 16, 16 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 512, 16, 16)
# USING Im2Col CONVOLUTION
# Input - ( 1, 512, 16, 16 )
# Output - ( 1, 512, 16, 16 )
# TIME ELAPSED - 3.8296 = 0.266816 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 512, 16, 16)
# Input - ( 1, 512, 16, 16 )
# Output - ( 1, 512, 16, 16 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 512, 16, 16)
# USING Im2Col CONVOLUTION
# Input - ( 1, 512, 16, 16 )
# Output - ( 1, 512, 16, 16 )
# TIME ELAPSED - 3.85587 = 0.270272 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 512, 16, 16)
# Input - ( 1, 512, 16, 16 )
# Output - ( 1, 512, 16, 16 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 512, 16, 16)
# USING Im2Col CONVOLUTION
# Input - ( 1, 512, 16, 16 )
# Output - ( 1, 512, 16, 16 )
# TIME ELAPSED - 3.85379 = 0.266944 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 512, 16, 16)
# Input - ( 1, 512, 16, 16 )
# Output - ( 1, 512, 16, 16 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 512, 16, 16)
# USING Im2Col CONVOLUTION
# Input - ( 1, 512, 16, 16 )
# Output - ( 1, 512, 16, 16 )
# TIME ELAPSED - 3.87149 = 0.271104 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 512, 16, 16)
# Input - ( 1, 512, 16, 16 )
# Output - ( 1, 512, 16, 16 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (1, 512, 8, 8)
# Input - ( 1, 512, 16, 16 )
# Output - ( 1, 512, 8, 8 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : ADAPTIVE_POOL(AVG, kernel_size = (2, 2), stride = (1 ,1), padding = (0 ,0)) --> (1, 512, 7, 7)
# Input - ( 1, 512, 8, 8 )
# Output - ( 1, 512, 7, 7 )
# Kernel Size - ( 2, 2 )
# Stride - ( 1, 1 )
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 25088) --> (1, 4096, 1, 1)
# Input - ( 1, 25088, 1, 1 )
# Output - ( 1, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 4096, 1, 1)
# Input - ( 1, 4096, 1, 1 )
# Output - ( 1, 4096, 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 4096) --> (1, 4096, 1, 1)
# Input - ( 1, 4096, 1, 1 )
# Output - ( 1, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 4096, 1, 1)
# Input - ( 1, 4096, 1, 1 )
# Output - ( 1, 4096, 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 1000, in_nodes = 4096) --> (1, 1000, 1, 1)
# Input - ( 1, 4096, 1, 1 )
# Output - ( 1, 1000, 1, 1 )
# ../forward/data/MiniImageNet/ImageLists.txt
# Running for Batchsize - 2
# Processing the Layer Type : CONV(64, 3, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 64, 256, 256)
# USING Im2Col CONVOLUTION
# Input - ( 2, 3, 256, 256 )
# Output - ( 2, 64, 256, 256 )
# TIME ELAPSED - 12.4087 = 0.339392 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 64, 256, 256)
# Input - ( 2, 64, 256, 256 )
# Output - ( 2, 64, 256, 256 )
# Processing the Layer Type : CONV(64, 64, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 64, 256, 256)
# USING Im2Col CONVOLUTION
# Input - ( 2, 64, 256, 256 )
# Output - ( 2, 64, 256, 256 )
# TIME ELAPSED - 25.6856 = 2.48006 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 64, 256, 256)
# Input - ( 2, 64, 256, 256 )
# Output - ( 2, 64, 256, 256 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (2, 64, 128, 128)
# Input - ( 2, 64, 256, 256 )
# Output - ( 2, 64, 128, 128 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(128, 64, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 128, 128, 128)
# USING Im2Col CONVOLUTION
# Input - ( 2, 64, 128, 128 )
# Output - ( 2, 128, 128, 128 )
# TIME ELAPSED - 11.9704 = 1.05558 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 128, 128, 128)
# Input - ( 2, 128, 128, 128 )
# Output - ( 2, 128, 128, 128 )
# Processing the Layer Type : CONV(128, 128, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 128, 128, 128)
# USING Im2Col CONVOLUTION
# Input - ( 2, 128, 128, 128 )
# Output - ( 2, 128, 128, 128 )
# TIME ELAPSED - 15.6286 = 1.87114 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 128, 128, 128)
# Input - ( 2, 128, 128, 128 )
# Output - ( 2, 128, 128, 128 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (2, 128, 64, 64)
# Input - ( 2, 128, 128, 128 )
# Output - ( 2, 128, 64, 64 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(256, 128, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 256, 64, 64)
# USING Im2Col CONVOLUTION
# Input - ( 2, 128, 64, 64 )
# Output - ( 2, 256, 64, 64 )
# TIME ELAPSED - 8.71293 = 0.897888 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 256, 64, 64)
# Input - ( 2, 256, 64, 64 )
# Output - ( 2, 256, 64, 64 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 256, 64, 64)
# USING Im2Col CONVOLUTION
# Input - ( 2, 256, 64, 64 )
# Output - ( 2, 256, 64, 64 )
# TIME ELAPSED - 10.3661 = 1.49568 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 256, 64, 64)
# Input - ( 2, 256, 64, 64 )
# Output - ( 2, 256, 64, 64 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 256, 64, 64)
# USING Im2Col CONVOLUTION
# Input - ( 2, 256, 64, 64 )
# Output - ( 2, 256, 64, 64 )
# TIME ELAPSED - 10.3945 = 1.49434 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 256, 64, 64)
# Input - ( 2, 256, 64, 64 )
# Output - ( 2, 256, 64, 64 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 256, 64, 64)
# USING Im2Col CONVOLUTION
# Input - ( 2, 256, 64, 64 )
# Output - ( 2, 256, 64, 64 )
# TIME ELAPSED - 10.7616 = 1.49731 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 256, 64, 64)
# Input - ( 2, 256, 64, 64 )
# Output - ( 2, 256, 64, 64 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (2, 256, 32, 32)
# Input - ( 2, 256, 64, 64 )
# Output - ( 2, 256, 32, 32 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(512, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 512, 32, 32)
# USING Im2Col CONVOLUTION
# Input - ( 2, 256, 32, 32 )
# Output - ( 2, 512, 32, 32 )
# TIME ELAPSED - 5.48662 = 0.814656 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 512, 32, 32)
# Input - ( 2, 512, 32, 32 )
# Output - ( 2, 512, 32, 32 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 512, 32, 32)
# USING Im2Col CONVOLUTION
# Input - ( 2, 512, 32, 32 )
# Output - ( 2, 512, 32, 32 )
# TIME ELAPSED - 8.62694 = 1.43165 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 512, 32, 32)
# Input - ( 2, 512, 32, 32 )
# Output - ( 2, 512, 32, 32 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 512, 32, 32)
# USING Im2Col CONVOLUTION
# Input - ( 2, 512, 32, 32 )
# Output - ( 2, 512, 32, 32 )
# TIME ELAPSED - 8.51955 = 1.4248 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 512, 32, 32)
# Input - ( 2, 512, 32, 32 )
# Output - ( 2, 512, 32, 32 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 512, 32, 32)
# USING Im2Col CONVOLUTION
# Input - ( 2, 512, 32, 32 )
# Output - ( 2, 512, 32, 32 )
# TIME ELAPSED - 8.63446 = 1.42966 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 512, 32, 32)
# Input - ( 2, 512, 32, 32 )
# Output - ( 2, 512, 32, 32 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (2, 512, 16, 16)
# Input - ( 2, 512, 32, 32 )
# Output - ( 2, 512, 16, 16 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 512, 16, 16)
# USING Im2Col CONVOLUTION
# Input - ( 2, 512, 16, 16 )
# Output - ( 2, 512, 16, 16 )
# TIME ELAPSED - 4.67315 = 0.475616 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 512, 16, 16)
# Input - ( 2, 512, 16, 16 )
# Output - ( 2, 512, 16, 16 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 512, 16, 16)
# USING Im2Col CONVOLUTION
# Input - ( 2, 512, 16, 16 )
# Output - ( 2, 512, 16, 16 )
# TIME ELAPSED - 4.96547 = 0.470464 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 512, 16, 16)
# Input - ( 2, 512, 16, 16 )
# Output - ( 2, 512, 16, 16 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 512, 16, 16)
# USING Im2Col CONVOLUTION
# Input - ( 2, 512, 16, 16 )
# Output - ( 2, 512, 16, 16 )
# TIME ELAPSED - 4.69325 = 0.469184 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 512, 16, 16)
# Input - ( 2, 512, 16, 16 )
# Output - ( 2, 512, 16, 16 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 512, 16, 16)
# USING Im2Col CONVOLUTION
# Input - ( 2, 512, 16, 16 )
# Output - ( 2, 512, 16, 16 )
# TIME ELAPSED - 4.6833 = 0.469888 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 512, 16, 16)
# Input - ( 2, 512, 16, 16 )
# Output - ( 2, 512, 16, 16 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (2, 512, 8, 8)
# Input - ( 2, 512, 16, 16 )
# Output - ( 2, 512, 8, 8 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : ADAPTIVE_POOL(AVG, kernel_size = (2, 2), stride = (1 ,1), padding = (0 ,0)) --> (2, 512, 7, 7)
# Input - ( 2, 512, 8, 8 )
# Output - ( 2, 512, 7, 7 )
# Kernel Size - ( 2, 2 )
# Stride - ( 1, 1 )
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 25088) --> (2, 4096, 1, 1)
# Input - ( 2, 25088, 1, 1 )
# Output - ( 2, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 4096, 1, 1)
# Input - ( 2, 4096, 1, 1 )
# Output - ( 2, 4096, 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 4096) --> (2, 4096, 1, 1)
# Input - ( 2, 4096, 1, 1 )
# Output - ( 2, 4096, 1, 1 )
# ...
# USING CUDNNN CONVOLUTION
# Workspace size: 0.375008MB
# Input - ( 4, 3, 256, 256 )
# Output - ( 4, 64, 256, 256 )
# TIME ELAPSED - 1.55459
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 64, 256, 256)
# Input - ( 4, 64, 256, 256 )
# Output - ( 4, 64, 256, 256 )
# Processing the Layer Type : CONV(64, 64, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 64, 256, 256)
# USING CUDNNN CONVOLUTION
# Workspace size: 0.390869MB
# Input - ( 4, 64, 256, 256 )
# Output - ( 4, 64, 256, 256 )
# TIME ELAPSED - 18.5959
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 64, 256, 256)
# Input - ( 4, 64, 256, 256 )
# Output - ( 4, 64, 256, 256 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (4, 64, 128, 128)
# Input - ( 4, 64, 256, 256 )
# Output - ( 4, 64, 128, 128 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(128, 64, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 128, 128, 128)
# USING CUDNNN CONVOLUTION
# Workspace size: 0.781738MB
# Input - ( 4, 64, 128, 128 )
# Output - ( 4, 128, 128, 128 )
# TIME ELAPSED - 5.46896
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 128, 128, 128)
# Input - ( 4, 128, 128, 128 )
# Output - ( 4, 128, 128, 128 )
# Processing the Layer Type : CONV(128, 128, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 128, 128, 128)
# USING CUDNNN CONVOLUTION
# Workspace size: 1.56299MB
# Input - ( 4, 128, 128, 128 )
# Output - ( 4, 128, 128, 128 )
# TIME ELAPSED - 9.56582
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 128, 128, 128)
# Input - ( 4, 128, 128, 128 )
# Output - ( 4, 128, 128, 128 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (4, 128, 64, 64)
# Input - ( 4, 128, 128, 128 )
# Output - ( 4, 128, 64, 64 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(256, 128, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 256, 64, 64)
# USING CUDNNN CONVOLUTION
# Workspace size: 3.12598MB
# Input - ( 4, 128, 64, 64 )
# Output - ( 4, 256, 64, 64 )
# TIME ELAPSED - 3.42074
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 256, 64, 64)
# Input - ( 4, 256, 64, 64 )
# Output - ( 4, 256, 64, 64 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 256, 64, 64)
# USING CUDNNN CONVOLUTION
# Workspace size: 6.25098MB
# Input - ( 4, 256, 64, 64 )
# Output - ( 4, 256, 64, 64 )
# TIME ELAPSED - 6.13709
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 256, 64, 64)
# Input - ( 4, 256, 64, 64 )
# Output - ( 4, 256, 64, 64 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 256, 64, 64)
# USING CUDNNN CONVOLUTION
# Workspace size: 6.25098MB
# Input - ( 4, 256, 64, 64 )
# Output - ( 4, 256, 64, 64 )
# TIME ELAPSED - 6.1889
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 256, 64, 64)
# Input - ( 4, 256, 64, 64 )
# Output - ( 4, 256, 64, 64 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 256, 64, 64)
# USING CUDNNN CONVOLUTION
# Workspace size: 6.25098MB
# Input - ( 4, 256, 64, 64 )
# Output - ( 4, 256, 64, 64 )
# TIME ELAPSED - 5.98426
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 256, 64, 64)
# Input - ( 4, 256, 64, 64 )
# Output - ( 4, 256, 64, 64 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (4, 256, 32, 32)
# Input - ( 4, 256, 64, 64 )
# Output - ( 4, 256, 32, 32 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(512, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 512, 32, 32)
# USING CUDNNN CONVOLUTION
# Workspace size: 12.502MB
# Input - ( 4, 256, 32, 32 )
# Output - ( 4, 512, 32, 32 )
# TIME ELAPSED - 3.07955
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 512, 32, 32)
# Input - ( 4, 512, 32, 32 )
# Output - ( 4, 512, 32, 32 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 512, 32, 32)
# USING CUDNNN CONVOLUTION
# Workspace size: 25.002MB
# Input - ( 4, 512, 32, 32 )
# Output - ( 4, 512, 32, 32 )
# TIME ELAPSED - 5.6985
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 512, 32, 32)
# Input - ( 4, 512, 32, 32 )
# Output - ( 4, 512, 32, 32 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 512, 32, 32)
# USING CUDNNN CONVOLUTION
# Workspace size: 25.002MB
# Input - ( 4, 512, 32, 32 )
# Output - ( 4, 512, 32, 32 )
# TIME ELAPSED - 5.74838
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 512, 32, 32)
# Input - ( 4, 512, 32, 32 )
# Output - ( 4, 512, 32, 32 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 512, 32, 32)
# USING CUDNNN CONVOLUTION
# Workspace size: 25.002MB
# Input - ( 4, 512, 32, 32 )
# Output - ( 4, 512, 32, 32 )
# TIME ELAPSED - 5.72547
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 512, 32, 32)
# Input - ( 4, 512, 32, 32 )
# Output - ( 4, 512, 32, 32 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (4, 512, 16, 16)
# Input - ( 4, 512, 32, 32 )
# Output - ( 4, 512, 16, 16 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 512, 16, 16)
# USING CUDNNN CONVOLUTION
# Workspace size: 25.002MB
# Input - ( 4, 512, 16, 16 )
# Output - ( 4, 512, 16, 16 )
# TIME ELAPSED - 3.37997
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 512, 16, 16)
# Input - ( 4, 512, 16, 16 )
# Output - ( 4, 512, 16, 16 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 512, 16, 16)
# USING CUDNNN CONVOLUTION
# Workspace size: 25.002MB
# Input - ( 4, 512, 16, 16 )
# Output - ( 4, 512, 16, 16 )
# TIME ELAPSED - 3.40819
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 512, 16, 16)
# Input - ( 4, 512, 16, 16 )
# Output - ( 4, 512, 16, 16 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 512, 16, 16)
# USING CUDNNN CONVOLUTION
# Workspace size: 25.002MB
# Input - ( 4, 512, 16, 16 )
# Output - ( 4, 512, 16, 16 )
# TIME ELAPSED - 3.48326
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 512, 16, 16)
# Input - ( 4, 512, 16, 16 )
# Output - ( 4, 512, 16, 16 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 512, 16, 16)
# USING CUDNNN CONVOLUTION
# Workspace size: 25.002MB
# Input - ( 4, 512, 16, 16 )
# Output - ( 4, 512, 16, 16 )
# TIME ELAPSED - 3.3784
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 512, 16, 16)
# Input - ( 4, 512, 16, 16 )
# Output - ( 4, 512, 16, 16 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (4, 512, 8, 8)
# Input - ( 4, 512, 16, 16 )
# Output - ( 4, 512, 8, 8 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : ADAPTIVE_POOL(AVG, kernel_size = (2, 2), stride = (1 ,1), padding = (0 ,0)) --> (4, 512, 7, 7)
# Input - ( 4, 512, 8, 8 )
# Output - ( 4, 512, 7, 7 )
# Kernel Size - ( 2, 2 )
# Stride - ( 1, 1 )
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 25088) --> (4, 4096, 1, 1)
# Input - ( 4, 25088, 1, 1 )
# Output - ( 4, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 4096, 1, 1)
# Input - ( 4, 4096, 1, 1 )
# Output - ( 4, 4096, 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 4096) --> (4, 4096, 1, 1)
# Input - ( 4, 4096, 1, 1 )
# Output - ( 4, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 4096, 1, 1)
# Input - ( 4, 4096, 1, 1 )
# Output - ( 4, 4096, 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 1000, in_nodes = 4096) --> (4, 1000, 1, 1)
# Input - ( 4, 4096, 1, 1 )
# Output - ( 4, 1000, 1, 1 )
# ../forward/data/MiniImageNet/ImageLists.txt
# Running for Batchsize - 8
# Processing the Layer Type : CONV(64, 3, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 64, 256, 256)
# USING CUDNNN CONVOLUTION
# Workspace size: 0.375008MB
# Input - ( 8, 3, 256, 256 )
# Output - ( 8, 64, 256, 256 )
# TIME ELAPSED - 2.61027
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 64, 256, 256)
# Input - ( 8, 64, 256, 256 )
# Output - ( 8, 64, 256, 256 )
# Processing the Layer Type : CONV(64, 64, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 64, 256, 256)
# USING CUDNNN CONVOLUTION
# Workspace size: 0.390869MB
# Input - ( 8, 64, 256, 256 )
# Output - ( 8, 64, 256, 256 )
# TIME ELAPSED - 35.7535
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 64, 256, 256)
# Input - ( 8, 64, 256, 256 )
# Output - ( 8, 64, 256, 256 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (8, 64, 128, 128)
# Input - ( 8, 64, 256, 256 )
# Output - ( 8, 64, 128, 128 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(128, 64, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 128, 128, 128)
# USING CUDNNN CONVOLUTION
# Workspace size: 0.781738MB
# Input - ( 8, 64, 128, 128 )
# Output - ( 8, 128, 128, 128 )
# TIME ELAPSED - 11.5642
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 128, 128, 128)
# Input - ( 8, 128, 128, 128 )
# Output - ( 8, 128, 128, 128 )
# Processing the Layer Type : CONV(128, 128, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 128, 128, 128)
# USING CUDNNN CONVOLUTION
# Workspace size: 1.56299MB
# Input - ( 8, 128, 128, 128 )
# Output - ( 8, 128, 128, 128 )
# TIME ELAPSED - 18.1804
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 128, 128, 128)
# Input - ( 8, 128, 128, 128 )
# Output - ( 8, 128, 128, 128 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (8, 128, 64, 64)
# Input - ( 8, 128, 128, 128 )
# Output - ( 8, 128, 64, 64 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(256, 128, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 256, 64, 64)
# USING CUDNNN CONVOLUTION
# Workspace size: 3.12598MB
# Input - ( 8, 128, 64, 64 )
# Output - ( 8, 256, 64, 64 )
# TIME ELAPSED - 5.84669
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 256, 64, 64)
# Input - ( 8, 256, 64, 64 )
# Output - ( 8, 256, 64, 64 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 256, 64, 64)
# USING CUDNNN CONVOLUTION
# Workspace size: 6.25098MB
# Input - ( 8, 256, 64, 64 )
# Output - ( 8, 256, 64, 64 )
# TIME ELAPSED - 11.5835
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 256, 64, 64)
# Input - ( 8, 256, 64, 64 )
# Output - ( 8, 256, 64, 64 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 256, 64, 64)
# USING CUDNNN CONVOLUTION
# Workspace size: 6.25098MB
# Input - ( 8, 256, 64, 64 )
# Output - ( 8, 256, 64, 64 )
# TIME ELAPSED - 10.827
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 256, 64, 64)
# Input - ( 8, 256, 64, 64 )
# Output - ( 8, 256, 64, 64 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 256, 64, 64)
# USING CUDNNN CONVOLUTION
# Workspace size: 6.25098MB
# Input - ( 8, 256, 64, 64 )
# Output - ( 8, 256, 64, 64 )
# TIME ELAPSED - 11.0502
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 256, 64, 64)
# Input - ( 8, 256, 64, 64 )
# Output - ( 8, 256, 64, 64 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (8, 256, 32, 32)
# Input - ( 8, 256, 64, 64 )
# Output - ( 8, 256, 32, 32 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(512, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 512, 32, 32)
# USING CUDNNN CONVOLUTION
# Workspace size: 12.502MB
# Input - ( 8, 256, 32, 32 )
# Output - ( 8, 512, 32, 32 )
# TIME ELAPSED - 4.61334
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 512, 32, 32)
# Input - ( 8, 512, 32, 32 )
# Output - ( 8, 512, 32, 32 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 512, 32, 32)
# USING CUDNNN CONVOLUTION
# Workspace size: 25.002MB
# Input - ( 8, 512, 32, 32 )
# Output - ( 8, 512, 32, 32 )
# TIME ELAPSED - 8.91098
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 512, 32, 32)
# Input - ( 8, 512, 32, 32 )
# Output - ( 8, 512, 32, 32 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 512, 32, 32)
# USING CUDNNN CONVOLUTION
# Workspace size: 25.002MB
# Input - ( 8, 512, 32, 32 )
# Output - ( 8, 512, 32, 32 )
# TIME ELAPSED - 8.77766
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 512, 32, 32)
# Input - ( 8, 512, 32, 32 )
# Output - ( 8, 512, 32, 32 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 512, 32, 32)
# USING CUDNNN CONVOLUTION
# Workspace size: 25.002MB
# Input - ( 8, 512, 32, 32 )
# Output - ( 8, 512, 32, 32 )
# TIME ELAPSED - 8.76851
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 512, 32, 32)
# Input - ( 8, 512, 32, 32 )
# Output - ( 8, 512, 32, 32 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (8, 512, 16, 16)
# Input - ( 8, 512, 32, 32 )
# Output - ( 8, 512, 16, 16 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 512, 16, 16)
# USING CUDNNN CONVOLUTION
# Workspace size: 25.002MB
# Input - ( 8, 512, 16, 16 )
# Output - ( 8, 512, 16, 16 )
# TIME ELAPSED - 4.50448
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 512, 16, 16)
# Input - ( 8, 512, 16, 16 )
# Output - ( 8, 512, 16, 16 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 512, 16, 16)
# USING CUDNNN CONVOLUTION
# Workspace size: 25.002MB
# Input - ( 8, 512, 16, 16 )
# Output - ( 8, 512, 16, 16 )
# TIME ELAPSED - 4.52845
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 512, 16, 16)
# Input - ( 8, 512, 16, 16 )
# Output - ( 8, 512, 16, 16 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 512, 16, 16)
# USING CUDNNN CONVOLUTION
# Workspace size: 25.002MB
# Input - ( 8, 512, 16, 16 )
# Output - ( 8, 512, 16, 16 )
# TIME ELAPSED - 5.13123
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 512, 16, 16)
# Input - ( 8, 512, 16, 16 )
# Output - ( 8, 512, 16, 16 )
# Processing the Layer Type : CONV(512, 512, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 512, 16, 16)
# USING CUDNNN CONVOLUTION
# Workspace size: 25.002MB
# Input - ( 8, 512, 16, 16 )
# Output - ( 8, 512, 16, 16 )
# TIME ELAPSED - 4.5488
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 512, 16, 16)
# Input - ( 8, 512, 16, 16 )
# Output - ( 8, 512, 16, 16 )
# Processing the Layer Type : POOL(MAX, kernel_size = (2, 2), stride = (2 ,2), padding = (0 ,0)) --> (8, 512, 8, 8)
# Input - ( 8, 512, 16, 16 )
# Output - ( 8, 512, 8, 8 )
# Kernel Size - ( 2, 2 )
# Stride - ( 2, 2 )
# Processing the Layer Type : ADAPTIVE_POOL(AVG, kernel_size = (2, 2), stride = (1 ,1), padding = (0 ,0)) --> (8, 512, 7, 7)
# Input - ( 8, 512, 8, 8 )
# Output - ( 8, 512, 7, 7 )
# Kernel Size - ( 2, 2 )
# Stride - ( 1, 1 )
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 25088) --> (8, 4096, 1, 1)
# Input - ( 8, 25088, 1, 1 )
# Output - ( 8, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 4096, 1, 1)
# Input - ( 8, 4096, 1, 1 )
# Output - ( 8, 4096, 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 4096) --> (8, 4096, 1, 1)
# Input - ( 8, 4096, 1, 1 )
# Output - ( 8, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 4096, 1, 1)
# Input - ( 8, 4096, 1, 1 )
# Output - ( 8, 4096, 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 1000, in_nodes = 4096) --> (8, 1000, 1, 1)
# Input - ( 8, 4096, 1, 1 )
# Output - ( 8, 1000, 1, 1 )

# %%
# !make run_alex
# Out:
# rm -f logVGG.txt
# ./test "ALEX" "/content/HP3-CNN-Inferencing/pretrained-models/alexnet.pb" "DIRECT"
# FOR THE ALGORITHM : DIRECT
# ../forward/data/MiniImageNet/ImageLists.txt
# Running for Batchsize - 1
# Processing the Layer Type : CONV(64, 3, kernel_size = (11, 11), stride = (4 ,4), padding = (2 ,2)) --> (1, 64, 63, 63)
# USING DIRECT CONVOLUTION
# Input - ( 1, 3, 256, 256 )
# TIME ELAPSED - 5.4753 = 2.78774 + 0.38192
# Output - ( 1, 64, 63, 63 )
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 64, 63, 63)
# Input - ( 1, 64, 63, 63 )
# Output - ( 1, 64, 63, 63 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (1, 64, 31, 31)
# Input - ( 1, 64, 63, 63 )
# Output - ( 1, 64, 31, 31 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(192, 64, kernel_size = (5, 5), stride = (1 ,1), padding = (2 ,2)) --> (1, 192, 31, 31)
# USING DIRECT CONVOLUTION
# Input - ( 1, 64, 31, 31 )
# TIME ELAPSED - 10.976 = 9.67824 + 0.150688
# Output - ( 1, 192, 31, 31 )
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 192, 31, 31)
# Input - ( 1, 192, 31, 31 )
# Output - ( 1, 192, 31, 31 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (1, 192, 15, 15)
# Input - ( 1, 192, 31, 31 )
# Output - ( 1, 192, 15, 15 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(384, 192, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 384, 15, 15)
# USING DIRECT CONVOLUTION
# Input - ( 1, 192, 15, 15 )
# TIME ELAPSED - 8.796 = 7.47034 + 0.113632
# Output - ( 1, 384, 15, 15 )
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 384, 15, 15)
# Input - ( 1, 384, 15, 15 )
# Output - ( 1, 384, 15, 15 )
# Processing the Layer Type : CONV(256, 384, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 256, 15, 15)
# USING DIRECT CONVOLUTION
# Input - ( 1, 384, 15, 15 )
# TIME ELAPSED - 11.9086 = 10.0565 + 0.210144
# Output - ( 1, 256, 15, 15 )
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 256, 15, 15)
# Input - ( 1, 256, 15, 15 )
# Output - ( 1, 256, 15, 15 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 256, 15, 15)
# USING DIRECT CONVOLUTION
# Input - ( 1, 256, 15, 15 )
# TIME ELAPSED - 8.02419 = 6.69466 + 0.14608
# Output - ( 1, 256, 15, 15 )
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 256, 15, 15)
# Input - ( 1, 256, 15, 15 )
# Output - ( 1, 256, 15, 15 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (1, 256, 7, 7)
# Input - ( 1, 256, 15, 15 )
# Output - ( 1, 256, 7, 7 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : ADAPTIVE_POOL(AVG, kernel_size = (2, 2), stride = (1 ,1), padding = (0 ,0)) --> (1, 256, 6, 6)
# Input - ( 1, 256, 7, 7 )
# Output - ( 1, 256, 6, 6 )
# Kernel Size - ( 2, 2 )
# Stride - ( 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 9216) --> (1, 4096, 1, 1)
# Input - ( 1, 9216, 1, 1 )
# Output - ( 1, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 4096, 1, 1)
# Input - ( 1, 4096, 1, 1 )
# Output - ( 1, 4096, 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 4096) --> (1, 4096, 1, 1)
# Input - ( 1, 4096, 1, 1 )
# Output - ( 1, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 4096, 1, 1)
# Input - ( 1, 4096, 1, 1 )
# Output - ( 1, 4096, 1, 1 )
# Processing the Layer Type : LINEAR(out_nodes = 1000, in_nodes = 4096) --> (1, 1000, 1, 1)
# Input - ( 1, 4096, 1, 1 )
# Output - ( 1, 1000, 1, 1 )
# ../forward/data/MiniImageNet/ImageLists.txt
# Running for Batchsize - 2
# Processing the Layer Type : CONV(64, 3, kernel_size = (11, 11), stride = (4 ,4), padding = (2 ,2)) --> (2, 64, 63, 63)
# USING DIRECT CONVOLUTION
# Input - ( 2, 3, 256, 256 )
# TIME ELAPSED - 9.61514 = 5.55405 + 0.756768
# Output - ( 2, 64, 63, 63 )
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 64, 63, 63)
# Input - ( 2, 64, 63, 63 )
# Output - ( 2, 64, 63, 63 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (2, 64, 31, 31)
# Input - ( 2, 64, 63, 63 )
# Output - ( 2, 64, 31, 31 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(192, 64, kernel_size = (5, 5), stride = (1 ,1), padding = (2 ,2)) --> (2, 192, 31, 31)
# USING DIRECT CONVOLUTION
# Input - ( 2, 64, 31, 31 )
# TIME ELAPSED - 21.8026 = 19.2671 + 0.30272
# Output - ( 2, 192, 31, 31 )
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 192, 31, 31)
# Input - ( 2, 192, 31, 31 )
# Output - ( 2, 192, 31, 31 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (2, 192, 15, 15)
# Input - ( 2, 192, 31, 31 )
# Output - ( 2, 192, 15, 15 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(384, 192, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 384, 15, 15)
# USING DIRECT CONVOLUTION
# Input - ( 2, 192, 15, 15 )
# TIME ELAPSED - 16.746 = 14.7804 + 0.220096
# Output - ( 2, 384, 15, 15 )
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 384, 15, 15)
# Input - ( 2, 384, 15, 15 )
# Output - ( 2, 384, 15, 15 )
# Processing the Layer Type : CONV(256, 384, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 256, 15, 15)
# USING DIRECT CONVOLUTION
# Input - ( 2, 384, 15, 15 )
# TIME ELAPSED - 22.4889 = 19.8611 + 0.422688
# Output - ( 2, 256, 15, 15 )
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 256, 15, 15)
# Input - ( 2, 256, 15, 15 )
# Output - ( 2, 256, 15, 15 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 256, 15, 15)
# USING DIRECT CONVOLUTION
# Input - ( 2, 256, 15, 15 )
# TIME ELAPSED - 15.3256 = 13.1598 + 0.282144
# Output - ( 2, 256, 15, 15 )
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 256, 15, 15)
# Input - ( 2, 256, 15, 15 )
# Output - ( 2, 256, 15, 15 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (2, 256, 7, 7)
# Input - ( 2, 256, 15, 15 )
# Output - ( 2, 256, 7, 7 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : ADAPTIVE_POOL(AVG, kernel_size = (2, 2), stride = (1 ,1), padding = (0 ,0)) --> (2, 256, 6, 6)
# Input - ( 2, 256, 7, 7 )
# Output - ( 2, 256, 6, 6 )
# Kernel Size - ( 2, 2 )
# Stride - ( 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 9216) --> (2, 4096, 1, 1)
# Input - ( 2, 9216, 1, 1 )
# Output - ( 2, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 4096, 1, 1)
# Input - ( 2, 4096, 1, 1 )
# Output - ( 2, 4096, 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 4096) --> (2, 4096, 1, 1)
# Input - ( 2, 4096, 1, 1 )
# Output - ( 2, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 4096, 1, 1)
# Input - ( 2, 4096, 1, 1 )
# Output - ( 2, 4096, 1, 1 )
# Processing the Layer Type : LINEAR(out_nodes = 1000, in_nodes = 4096) --> (2, 1000, 1, 1)
# Input - ( 2, 4096, 1, 1 )
# Output - ( 2, 1000, 1, 1 )
# ../forward/data/MiniImageNet/ImageLists.txt
# Running for Batchsize - 4
# Processing the Layer Type : CONV(64, 3, kernel_size = (11, 11), stride = (4 ,4), padding = (2 ,2)) --> (4, 64, 63, 63)
# USING DIRECT CONVOLUTION
# Input - ( 4, 3, 256, 256 )
# TIME ELAPSED - 17.8732 = 11.1422 + 1.4967
# Output - ( 4, 64, 63, 63 )
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 64, 63, 63)
# Input - ( 4, 64, 63, 63 )
# Output - ( 4, 64, 63, 63 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (4, 64, 31, 31)
# Input - ( 4, 64, 63, 63 )
# Output - ( 4, 64, 31, 31 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(192, 64, kernel_size = (5, 5), stride = (1 ,1), padding = (2 ,2)) --> (4, 192, 31, 31)
# USING DIRECT CONVOLUTION
# Input - ( 4, 64, 31, 31 )
# TIME ELAPSED - 42.0995 = 38.3124 + 0.600992
# Output - ( 4, 192, 31, 31 )
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 192, 31, 31)
# Input - ( 4, 192, 31, 31 )
# Output - ( 4, 192, 31, 31 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (4, 192, 15, 15)
# Input - ( 4, 192, 31, 31 )
# Output - ( 4, 192, 15, 15 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(384, 192, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 384, 15, 15)
# USING DIRECT CONVOLUTION
# Input - ( 4, 192, 15, 15 )
# TIME ELAPSED - 32.2248 = 29.341 + 0.430816
# Output - ( 4, 384, 15, 15 )
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 384, 15, 15)
# Input - ( 4, 384, 15, 15 )
# Output - ( 4, 384, 15, 15 )
# Processing the Layer Type : CONV(256, 384, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 256, 15, 15)
# USING DIRECT CONVOLUTION
# Input - ( 4, 384, 15, 15 )
# TIME ELAPSED - 44.4302 = 40.2334 + 0.8328
# Output - ( 4, 256, 15, 15 )
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 256, 15, 15)
# Input - ( 4, 256, 15, 15 )
# Output - ( 4, 256, 15, 15 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 256, 15, 15)
# USING DIRECT CONVOLUTION
# Input - ( 4, 256, 15, 15 )
# TIME ELAPSED - 29.49 = 26.1323 + 0.565344
# Output - ( 4, 256, 15, 15 )
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 256, 15, 15)
# Input - ( 4, 256, 15, 15 )
# Output - ( 4, 256, 15, 15 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (4, 256, 7, 7)
# Input - ( 4, 256, 15, 15 )
# Output - ( 4, 256, 7, 7 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : ADAPTIVE_POOL(AVG, kernel_size = (2, 2), stride = (1 ,1), padding = (0 ,0)) --> (4, 256, 6, 6)
# Input - ( 4, 256, 7, 7 )
# Output - ( 4, 256, 6, 6 )
# Kernel Size - ( 2, 2 )
# Stride - ( 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 9216) --> (4, 4096, 1, 1)
# Input - ( 4, 9216, 1, 1 )
# Output - ( 4, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 4096, 1, 1)
# Input - ( 4, 4096, 1, 1 )
# Output - ( 4, 4096, 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 4096) --> (4, 4096, 1, 1)
# Input - ( 4, 4096, 1, 1 )
# Output - ( 4, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 4096, 1, 1)
# Input - ( 4, 4096, 1, 1 )
# Output - ( 4, 4096, 1, 1 )
# Processing the Layer Type : LINEAR(out_nodes = 1000, in_nodes = 4096) --> (4, 1000, 1, 1)
# Input - ( 4, 4096, 1, 1 )
# Output - ( 4, 1000, 1, 1 )
# ../forward/data/MiniImageNet/ImageLists.txt
# Running for Batchsize - 8
# Processing the Layer Type : CONV(64, 3, kernel_size = (11, 11), stride = (4 ,4), padding = (2 ,2)) --> (8, 64, 63, 63)
# USING DIRECT CONVOLUTION
# Input - ( 8, 3, 256, 256 )
# TIME ELAPSED - 33.5712 = 20.8579 + 2.80992
# Output - ( 8, 64, 63, 63 )
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 64, 63, 63)
# Input - ( 8, 64, 63, 63 )
# Output - ( 8, 64, 63, 63 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (8, 64, 31, 31)
# Input - ( 8, 64, 63, 63 )
# Output - ( 8, 64, 31, 31 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(192, 64, kernel_size = (5, 5), stride = (1 ,1), padding = (2 ,2)) --> (8, 192, 31, 31)
# USING DIRECT CONVOLUTION
# Input - ( 8, 64, 31, 31 )
# TIME ELAPSED - 78.3207 = 71.2242 + 1.13459
# Output - ( 8, 192, 31, 31 )
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 192, 31, 31)
# Input - ( 8, 192, 31, 31 )
# Output - ( 8, 192, 31, 31 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (8, 192, 15, 15)
# Input - ( 8, 192, 31, 31 )
# Output - ( 8, 192, 15, 15 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(384, 192, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 384, 15, 15)
# USING DIRECT CONVOLUTION
# Input - ( 8, 192, 15, 15 )
# TIME ELAPSED - 59.6139 = 54.7731 + 0.820704
# Output - ( 8, 384, 15, 15 )
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 384, 15, 15)
# Input - ( 8, 384, 15, 15 )
# Output - ( 8, 384, 15, 15 )
# Processing the Layer Type : CONV(256, 384, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 256, 15, 15)
# USING DIRECT CONVOLUTION
# Input - ( 8, 384, 15, 15 )
# TIME ELAPSED - 82.8391 = 75.7848 + 1.57488
# Output - ( 8, 256, 15, 15 )
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 256, 15, 15)
# Input - ( 8, 256, 15, 15 )
# Output - ( 8, 256, 15, 15 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 256, 15, 15)
# USING DIRECT CONVOLUTION
# Input - ( 8, 256, 15, 15 )
# TIME ELAPSED - 53.6245 = 48.5355 + 1.07526
# Output - ( 8, 256, 15, 15 )
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 256, 15, 15)
# Input - ( 8, 256, 15, 15 )
# Output - ( 8, 256, 15, 15 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (8, 256, 7, 7)
# Input - ( 8, 256, 15, 15 )
# Output - ( 8, 256, 7, 7 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : ADAPTIVE_POOL(AVG, kernel_size = (2, 2), stride = (1 ,1), padding = (0 ,0)) --> (8, 256, 6, 6)
# Input - ( 8, 256, 7, 7 )
# Output - ( 8, 256, 6, 6 )
# Kernel Size - ( 2, 2 )
# Stride - ( 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 9216) --> (8, 4096, 1, 1)
# Input - ( 8, 9216, 1, 1 )
# Output - ( 8, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 4096, 1, 1)
# Input - ( 8, 4096, 1, 1 )
# Output - ( 8, 4096, 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 4096) --> (8, 4096, 1, 1)
# Input - ( 8, 4096, 1, 1 )
# Output - ( 8, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 4096, 1, 1)
# Input - ( 8, 4096, 1, 1 )
# Output - ( 8, 4096, 1, 1 )
# Processing the Layer Type : LINEAR(out_nodes = 1000, in_nodes = 4096) --> (8, 1000, 1, 1)
# Input - ( 8, 4096, 1, 1 )
# Output - ( 8, 1000, 1, 1 )
# ./test "ALEX" "/content/HP3-CNN-Inferencing/pretrained-models/alexnet.pb" "IM2COL"
# FOR THE ALGORITHM : IM2COL
# ../forward/data/MiniImageNet/ImageLists.txt
# Running for Batchsize - 1
# Processing the Layer Type : CONV(64, 3, kernel_size = (11, 11), stride = (4 ,4), padding = (2 ,2)) --> (1, 64, 63, 63)
# USING Im2Col CONVOLUTION
# Input - ( 1, 3, 256, 256 )
# Output - ( 1, 64, 63, 63 )
# TIME ELAPSED - 1.68902 = 0.127008 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 64, 63, 63)
# Input - ( 1, 64, 63, 63 )
# Output - ( 1, 64, 63, 63 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (1, 64, 31, 31)
# Input - ( 1, 64, 63, 63 )
# Output - ( 1, 64, 31, 31 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(192, 64, kernel_size = (5, 5), stride = (1 ,1), padding = (2 ,2)) --> (1, 192, 31, 31)
# USING Im2Col CONVOLUTION
# Input - ( 1, 64, 31, 31 )
# Output - ( 1, 192, 31, 31 )
# TIME ELAPSED - 1.71245 = 0.254656 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 192, 31, 31)
# Input - ( 1, 192, 31, 31 )
# Output - ( 1, 192, 31, 31 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (1, 192, 15, 15)
# Input - ( 1, 192, 31, 31 )
# Output - ( 1, 192, 15, 15 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(384, 192, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 384, 15, 15)
# USING Im2Col CONVOLUTION
# Input - ( 1, 192, 15, 15 )
# Output - ( 1, 384, 15, 15 )
# TIME ELAPSED - 1.64365 = 0.107232 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 384, 15, 15)
# Input - ( 1, 384, 15, 15 )
# Output - ( 1, 384, 15, 15 )
# Processing the Layer Type : CONV(256, 384, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 256, 15, 15)
# USING Im2Col CONVOLUTION
# Input - ( 1, 384, 15, 15 )
# Output - ( 1, 256, 15, 15 )
# TIME ELAPSED - 1.8375 = 0.187936 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 256, 15, 15)
# Input - ( 1, 256, 15, 15 )
# Output - ( 1, 256, 15, 15 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 256, 15, 15)
# USING Im2Col CONVOLUTION
# Input - ( 1, 256, 15, 15 )
# Output - ( 1, 256, 15, 15 )
# TIME ELAPSED - 1.39949 = 0.131744 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 256, 15, 15)
# Input - ( 1, 256, 15, 15 )
# Output - ( 1, 256, 15, 15 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (1, 256, 7, 7)
# Input - ( 1, 256, 15, 15 )
# Output - ( 1, 256, 7, 7 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : ADAPTIVE_POOL(AVG, kernel_size = (2, 2), stride = (1 ,1), padding = (0 ,0)) --> (1, 256, 6, 6)
# Input - ( 1, 256, 7, 7 )
# Output - ( 1, 256, 6, 6 )
# Kernel Size - ( 2, 2 )
# Stride - ( 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 9216) --> (1, 4096, 1, 1)
# Input - ( 1, 9216, 1, 1 )
# Output - ( 1, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 4096, 1, 1)
# Input - ( 1, 4096, 1, 1 )
# Output - ( 1, 4096, 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 4096) --> (1, 4096, 1, 1)
# Input - ( 1, 4096, 1, 1 )
# Output - ( 1, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 4096, 1, 1)
# Input - ( 1, 4096, 1, 1 )
# Output - ( 1, 4096, 1, 1 )
# Processing the Layer Type : LINEAR(out_nodes = 1000, in_nodes = 4096) --> (1, 1000, 1, 1)
# Input - ( 1, 4096, 1, 1 )
# Output - ( 1, 1000, 1, 1 )
# ../forward/data/MiniImageNet/ImageLists.txt
# Running for Batchsize - 2
# Processing the Layer Type : CONV(64, 3, kernel_size = (11, 11), stride = (4 ,4), padding = (2 ,2)) --> (2, 64, 63, 63)
# USING Im2Col CONVOLUTION
# Input - ( 2, 3, 256, 256 )
# Output - ( 2, 64, 63, 63 )
# TIME ELAPSED - 2.91389 = 0.21632 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 64, 63, 63)
# Input - ( 2, 64, 63, 63 )
# Output - ( 2, 64, 63, 63 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (2, 64, 31, 31)
# Input - ( 2, 64, 63, 63 )
# Output - ( 2, 64, 31, 31 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(192, 64, kernel_size = (5, 5), stride = (1 ,1), padding = (2 ,2)) --> (2, 192, 31, 31)
# USING Im2Col CONVOLUTION
# Input - ( 2, 64, 31, 31 )
# Output - ( 2, 192, 31, 31 )
# TIME ELAPSED - 2.71286 = 0.495744 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 192, 31, 31)
# Input - ( 2, 192, 31, 31 )
# Output - ( 2, 192, 31, 31 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (2, 192, 15, 15)
# Input - ( 2, 192, 31, 31 )
# Output - ( 2, 192, 15, 15 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(384, 192, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 384, 15, 15)
# USING Im2Col CONVOLUTION
# Input - ( 2, 192, 15, 15 )
# Output - ( 2, 384, 15, 15 )
# TIME ELAPSED - 1.95098 = 0.216256 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 384, 15, 15)
# Input - ( 2, 384, 15, 15 )
# Output - ( 2, 384, 15, 15 )
# Processing the Layer Type : CONV(256, 384, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 256, 15, 15)
# USING Im2Col CONVOLUTION
# Input - ( 2, 384, 15, 15 )
# Output - ( 2, 256, 15, 15 )
# TIME ELAPSED - 2.49267 = 0.372864 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 256, 15, 15)
# Input - ( 2, 256, 15, 15 )
# Output - ( 2, 256, 15, 15 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 256, 15, 15)
# USING Im2Col CONVOLUTION
# Input - ( 2, 256, 15, 15 )
# Output - ( 2, 256, 15, 15 )
# TIME ELAPSED - 1.76691 = 0.25872 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 256, 15, 15)
# Input - ( 2, 256, 15, 15 )
# Output - ( 2, 256, 15, 15 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (2, 256, 7, 7)
# Input - ( 2, 256, 15, 15 )
# Output - ( 2, 256, 7, 7 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : ADAPTIVE_POOL(AVG, kernel_size = (2, 2), stride = (1 ,1), padding = (0 ,0)) --> (2, 256, 6, 6)
# Input - ( 2, 256, 7, 7 )
# Output - ( 2, 256, 6, 6 )
# Kernel Size - ( 2, 2 )
# Stride - ( 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 9216) --> (2, 4096, 1, 1)
# Input - ( 2, 9216, 1, 1 )
# Output - ( 2, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 4096, 1, 1)
# Input - ( 2, 4096, 1, 1 )
# Output - ( 2, 4096, 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 4096) --> (2, 4096, 1, 1)
# Input - ( 2, 4096, 1, 1 )
# Output - ( 2, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 4096, 1, 1)
# Input - ( 2, 4096, 1, 1 )
# Output - ( 2, 4096, 1, 1 )
# Processing the Layer Type : LINEAR(out_nodes = 1000, in_nodes = 4096) --> (2, 1000, 1, 1)
# Input - ( 2, 4096, 1, 1 )
# Output - ( 2, 1000, 1, 1 )
# ../forward/data/MiniImageNet/ImageLists.txt
# Running for Batchsize - 4
# Processing the Layer Type : CONV(64, 3, kernel_size = (11, 11), stride = (4 ,4), padding = (2 ,2)) --> (4, 64, 63, 63)
# USING Im2Col CONVOLUTION
# Input - ( 4, 3, 256, 256 )
# Output - ( 4, 64, 63, 63 )
# TIME ELAPSED - 4.62384 = 0.42624 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 64, 63, 63)
# Input - ( 4, 64, 63, 63 )
# Output - ( 4, 64, 63, 63 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (4, 64, 31, 31)
# Input - ( 4, 64, 63, 63 )
# Output - ( 4, 64, 31, 31 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(192, 64, kernel_size = (5, 5), stride = (1 ,1), padding = (2 ,2)) --> (4, 192, 31, 31)
# USING Im2Col CONVOLUTION
# Input - ( 4, 64, 31, 31 )
# Output - ( 4, 192, 31, 31 )
# TIME ELAPSED - 4.42717 = 0.992384 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 192, 31, 31)
# Input - ( 4, 192, 31, 31 )
# Output - ( 4, 192, 31, 31 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (4, 192, 15, 15)
# Input - ( 4, 192, 31, 31 )
# Output - ( 4, 192, 15, 15 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(384, 192, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 384, 15, 15)
# USING Im2Col CONVOLUTION
# Input - ( 4, 192, 15, 15 )
# Output - ( 4, 384, 15, 15 )
# TIME ELAPSED - 3.09056 = 0.411136 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 384, 15, 15)
# Input - ( 4, 384, 15, 15 )
# Output - ( 4, 384, 15, 15 )
# Processing the Layer Type : CONV(256, 384, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 256, 15, 15)
# USING Im2Col CONVOLUTION
# Input - ( 4, 384, 15, 15 )
# Output - ( 4, 256, 15, 15 )
# TIME ELAPSED - 3.71846 = 0.742336 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 256, 15, 15)
# Input - ( 4, 256, 15, 15 )
# Output - ( 4, 256, 15, 15 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 256, 15, 15)
# USING Im2Col CONVOLUTION
# Input - ( 4, 256, 15, 15 )
# Output - ( 4, 256, 15, 15 )
# TIME ELAPSED - 2.96998 = 0.518272 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 256, 15, 15)
# Input - ( 4, 256, 15, 15 )
# Output - ( 4, 256, 15, 15 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (4, 256, 7, 7)
# Input - ( 4, 256, 15, 15 )
# Output - ( 4, 256, 7, 7 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : ADAPTIVE_POOL(AVG, kernel_size = (2, 2), stride = (1 ,1), padding = (0 ,0)) --> (4, 256, 6, 6)
# Input - ( 4, 256, 7, 7 )
# Output - ( 4, 256, 6, 6 )
# Kernel Size - ( 2, 2 )
# Stride - ( 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 9216) --> (4, 4096, 1, 1)
# Input - ( 4, 9216, 1, 1 )
# Output - ( 4, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 4096, 1, 1)
# Input - ( 4, 4096, 1, 1 )
# Output - ( 4, 4096, 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 4096) --> (4, 4096, 1, 1)
# Input - ( 4, 4096, 1, 1 )
# Output - ( 4, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 4096, 1, 1)
# Input - ( 4, 4096, 1, 1 )
# Output - ( 4, 4096, 1, 1 )
# Processing the Layer Type : LINEAR(out_nodes = 1000, in_nodes = 4096) --> (4, 1000, 1, 1)
# Input - ( 4, 4096, 1, 1 )
# Output - ( 4, 1000, 1, 1 )
# ../forward/data/MiniImageNet/ImageLists.txt
# Running for Batchsize - 8
# Processing the Layer Type : CONV(64, 3, kernel_size = (11, 11), stride = (4 ,4), padding = (2 ,2)) --> (8, 64, 63, 63)
# USING Im2Col CONVOLUTION
# Input - ( 8, 3, 256, 256 )
# Output - ( 8, 64, 63, 63 )
# TIME ELAPSED - 8.03162 = 0.846528 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 64, 63, 63)
# Input - ( 8, 64, 63, 63 )
# Output - ( 8, 64, 63, 63 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (8, 64, 31, 31)
# Input - ( 8, 64, 63, 63 )
# Output - ( 8, 64, 31, 31 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(192, 64, kernel_size = (5, 5), stride = (1 ,1), padding = (2 ,2)) --> (8, 192, 31, 31)
# USING Im2Col CONVOLUTION
# Input - ( 8, 64, 31, 31 )
# Output - ( 8, 192, 31, 31 )
# TIME ELAPSED - 7.83885 = 1.97885 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 192, 31, 31)
# Input - ( 8, 192, 31, 31 )
# Output - ( 8, 192, 31, 31 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (8, 192, 15, 15)
# Input - ( 8, 192, 31, 31 )
# Output - ( 8, 192, 15, 15 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(384, 192, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 384, 15, 15)
# USING Im2Col CONVOLUTION
# Input - ( 8, 192, 15, 15 )
# Output - ( 8, 384, 15, 15 )
# TIME ELAPSED - 4.51325 = 0.809248 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 384, 15, 15)
# Input - ( 8, 384, 15, 15 )
# Output - ( 8, 384, 15, 15 )
# Processing the Layer Type : CONV(256, 384, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 256, 15, 15)
# USING Im2Col CONVOLUTION
# Input - ( 8, 384, 15, 15 )
# Output - ( 8, 256, 15, 15 )
# TIME ELAPSED - 5.8639 = 1.47232 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 256, 15, 15)
# Input - ( 8, 256, 15, 15 )
# Output - ( 8, 256, 15, 15 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 256, 15, 15)
# USING Im2Col CONVOLUTION
# Input - ( 8, 256, 15, 15 )
# Output - ( 8, 256, 15, 15 )
# TIME ELAPSED - 4.50096 = 1.02534 + 0.01
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 256, 15, 15)
# Input - ( 8, 256, 15, 15 )
# Output - ( 8, 256, 15, 15 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (8, 256, 7, 7)
# Input - ( 8, 256, 15, 15 )
# Output - ( 8, 256, 7, 7 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : ADAPTIVE_POOL(AVG, kernel_size = (2, 2), stride = (1 ,1), padding = (0 ,0)) --> (8, 256, 6, 6)
# Input - ( 8, 256, 7, 7 )
# Output - ( 8, 256, 6, 6 )
# Kernel Size - ( 2, 2 )
# Stride - ( 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 9216) --> (8, 4096, 1, 1)
# Input - ( 8, 9216, 1, 1 )
# Output - ( 8, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 4096, 1, 1)
# Input - ( 8, 4096, 1, 1 )
# Output - ( 8, 4096, 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 4096) --> (8, 4096, 1, 1)
# Input - ( 8, 4096, 1, 1 )
# Output - ( 8, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 4096, 1, 1)
# Input - ( 8, 4096, 1, 1 )
# Output - ( 8, 4096, 1, 1 )
# Processing the Layer Type : LINEAR(out_nodes = 1000, in_nodes = 4096) --> (8, 1000, 1, 1)
# Input - ( 8, 4096, 1, 1 )
# Output - ( 8, 1000, 1, 1 )
# ./test "ALEX" "/content/HP3-CNN-Inferencing/pretrained-models/alexnet.pb" "FFT"
# FOR THE ALGORITHM : FFT
# ../forward/data/MiniImageNet/ImageLists.txt
# Running for Batchsize - 1
# Processing the Layer Type : CONV(64, 3, kernel_size = (11, 11), stride = (4 ,4), padding = (2 ,2)) --> (1, 64, 63, 63)
# USING FFT CONVOLUTION
# Input - ( 1, 3, 256, 256 )
# Output - ( 1, 64, 63, 63 )
# TIME ELAPSED - 238.62 = 218.487 + 3.1367
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 64, 63, 63)
# Input - ( 1, 64, 63, 63 )
# Output - ( 1, 64, 63, 63 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (1, 64, 31, 31)
# Input - ( 1, 64, 63, 63 )
# Output - ( 1, 64, 31, 31 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(192, 64, kernel_size = (5, 5), stride = (1 ,1), padding = (2 ,2)) --> (1, 192, 31, 31)
# USING FFT CONVOLUTION
# Input - ( 1, 64, 31, 31 )
# Output - ( 1, 192, 31, 31 )
# TIME ELAPSED - 30.115 = 6.96938 + 3.15485
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 192, 31, 31)
# Input - ( 1, 192, 31, 31 )
# Output - ( 1, 192, 31, 31 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (1, 192, 15, 15)
# Input - ( 1, 192, 31, 31 )
# Output - ( 1, 192, 15, 15 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(384, 192, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 384, 15, 15)
# USING FFT CONVOLUTION
# Input - ( 1, 192, 15, 15 )
# Output - ( 1, 384, 15, 15 )
# TIME ELAPSED - 58.9528 = 29.2037 + 3.65475
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 384, 15, 15)
# Input - ( 1, 384, 15, 15 )
# Output - ( 1, 384, 15, 15 )
# Processing the Layer Type : CONV(256, 384, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 256, 15, 15)
# USING FFT CONVOLUTION
# Input - ( 1, 384, 15, 15 )
# Output - ( 1, 256, 15, 15 )
# TIME ELAPSED - 100.737 = 39.622 + 5.03971
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 256, 15, 15)
# Input - ( 1, 256, 15, 15 )
# Output - ( 1, 256, 15, 15 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 256, 15, 15)
# USING FFT CONVOLUTION
# Input - ( 1, 256, 15, 15 )
# Output - ( 1, 256, 15, 15 )
# TIME ELAPSED - 94.8972 = 33.7687 + 3.44803
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 256, 15, 15)
# Input - ( 1, 256, 15, 15 )
# Output - ( 1, 256, 15, 15 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (1, 256, 7, 7)
# Input - ( 1, 256, 15, 15 )
# Output - ( 1, 256, 7, 7 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : ADAPTIVE_POOL(AVG, kernel_size = (2, 2), stride = (1 ,1), padding = (0 ,0)) --> (1, 256, 6, 6)
# Input - ( 1, 256, 7, 7 )
# Output - ( 1, 256, 6, 6 )
# Kernel Size - ( 2, 2 )
# Stride - ( 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 9216) --> (1, 4096, 1, 1)
# Input - ( 1, 9216, 1, 1 )
# Output - ( 1, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 4096, 1, 1)
# Input - ( 1, 4096, 1, 1 )
# Output - ( 1, 4096, 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 4096) --> (1, 4096, 1, 1)
# Input - ( 1, 4096, 1, 1 )
# Output - ( 1, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 4096, 1, 1)
# Input - ( 1, 4096, 1, 1 )
# Output - ( 1, 4096, 1, 1 )
# Processing the Layer Type : LINEAR(out_nodes = 1000, in_nodes = 4096) --> (1, 1000, 1, 1)
# Input - ( 1, 4096, 1, 1 )
# Output - ( 1, 1000, 1, 1 )
# ../forward/data/MiniImageNet/ImageLists.txt
# Running for Batchsize - 2
# Processing the Layer Type : CONV(64, 3, kernel_size = (11, 11), stride = (4 ,4), padding = (2 ,2)) --> (2, 64, 63, 63)
# USING FFT CONVOLUTION
# Input - ( 2, 3, 256, 256 )
# Output - ( 2, 64, 63, 63 )
# TIME ELAPSED - 36.7948 = 9.64563 + 3.2129
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 64, 63, 63)
# Input - ( 2, 64, 63, 63 )
# Output - ( 2, 64, 63, 63 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (2, 64, 31, 31)
# Input - ( 2, 64, 63, 63 )
# Output - ( 2, 64, 31, 31 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(192, 64, kernel_size = (5, 5), stride = (1 ,1), padding = (2 ,2)) --> (2, 192, 31, 31)
# USING FFT CONVOLUTION
# Input - ( 2, 64, 31, 31 )
# Output - ( 2, 192, 31, 31 )
# TIME ELAPSED - 48.22 = 10.9061 + 3.4008
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 192, 31, 31)
# Input - ( 2, 192, 31, 31 )
# Output - ( 2, 192, 31, 31 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (2, 192, 15, 15)
# Input - ( 2, 192, 31, 31 )
# Output - ( 2, 192, 15, 15 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(384, 192, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 384, 15, 15)
# USING FFT CONVOLUTION
# Input - ( 2, 192, 15, 15 )
# Output - ( 2, 384, 15, 15 )
# TIME ELAPSED - 105.809 = 58.1497 + 3.83069
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 384, 15, 15)
# Input - ( 2, 384, 15, 15 )
# Output - ( 2, 384, 15, 15 )
# Processing the Layer Type : CONV(256, 384, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 256, 15, 15)
# USING FFT CONVOLUTION
# Input - ( 2, 384, 15, 15 )
# Output - ( 2, 256, 15, 15 )
# TIME ELAPSED - 168.563 = 78.6078 + 5.1104
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 256, 15, 15)
# Input - ( 2, 256, 15, 15 )
# Output - ( 2, 256, 15, 15 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 256, 15, 15)
# USING FFT CONVOLUTION
# Input - ( 2, 256, 15, 15 )
# Output - ( 2, 256, 15, 15 )
# TIME ELAPSED - 140.373 = 58.9461 + 3.6065
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 256, 15, 15)
# Input - ( 2, 256, 15, 15 )
# Output - ( 2, 256, 15, 15 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (2, 256, 7, 7)
# Input - ( 2, 256, 15, 15 )
# Output - ( 2, 256, 7, 7 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : ADAPTIVE_POOL(AVG, kernel_size = (2, 2), stride = (1 ,1), padding = (0 ,0)) --> (2, 256, 6, 6)
# Input - ( 2, 256, 7, 7 )
# Output - ( 2, 256, 6, 6 )
# Kernel Size - ( 2, 2 )
# Stride - ( 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 9216) --> (2, 4096, 1, 1)
# Input - ( 2, 9216, 1, 1 )
# Output - ( 2, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 4096, 1, 1)
# Input - ( 2, 4096, 1, 1 )
# Output - ( 2, 4096, 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 4096) --> (2, 4096, 1, 1)
# Input - ( 2, 4096, 1, 1 )
# Output - ( 2, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 4096, 1, 1)
# Input - ( 2, 4096, 1, 1 )
# Output - ( 2, 4096, 1, 1 )
# Processing the Layer Type : LINEAR(out_nodes = 1000, in_nodes = 4096) --> (2, 1000, 1, 1)
# Input - ( 2, 4096, 1, 1 )
# Output - ( 2, 1000, 1, 1 )
# ../forward/data/MiniImageNet/ImageLists.txt
# Running for Batchsize - 4
# Processing the Layer Type : CONV(64, 3, kernel_size = (11, 11), stride = (4 ,4), padding = (2 ,2)) --> (4, 64, 63, 63)
# USING FFT CONVOLUTION
# Input - ( 4, 3, 256, 256 )
# Output - ( 4, 64, 63, 63 )
# TIME ELAPSED - 59.0343 = 16.1647 + 3.88634
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 64, 63, 63)
# Input - ( 4, 64, 63, 63 )
# Output - ( 4, 64, 63, 63 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (4, 64, 31, 31)
# Input - ( 4, 64, 63, 63 )
# Output - ( 4, 64, 31, 31 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(192, 64, kernel_size = (5, 5), stride = (1 ,1), padding = (2 ,2)) --> (4, 192, 31, 31)
# USING FFT CONVOLUTION
# Input - ( 4, 64, 31, 31 )
# Output - ( 4, 192, 31, 31 )
# TIME ELAPSED - 82.0118 = 19.6677 + 3.95936
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 192, 31, 31)
# Input - ( 4, 192, 31, 31 )
# Output - ( 4, 192, 31, 31 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (4, 192, 15, 15)
# Input - ( 4, 192, 31, 31 )
# Output - ( 4, 192, 15, 15 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(384, 192, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 384, 15, 15)
# USING FFT CONVOLUTION
# Input - ( 4, 192, 15, 15 )
# Output - ( 4, 384, 15, 15 )
# TIME ELAPSED - 218.577 = 118.962 + 4.35926
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 384, 15, 15)
# Input - ( 4, 384, 15, 15 )
# Output - ( 4, 384, 15, 15 )
# Processing the Layer Type : CONV(256, 384, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 256, 15, 15)
# USING FFT CONVOLUTION
# Input - ( 4, 384, 15, 15 )
# Output - ( 4, 256, 15, 15 )
# TIME ELAPSED - 280.76 = 156.18 + 5.57536
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 256, 15, 15)
# Input - ( 4, 256, 15, 15 )
# Output - ( 4, 256, 15, 15 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 256, 15, 15)
# USING FFT CONVOLUTION
# Input - ( 4, 256, 15, 15 )
# Output - ( 4, 256, 15, 15 )
# TIME ELAPSED - 233.979 = 116.906 + 4.07702
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 256, 15, 15)
# Input - ( 4, 256, 15, 15 )
# Output - ( 4, 256, 15, 15 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (4, 256, 7, 7)
# Input - ( 4, 256, 15, 15 )
# Output - ( 4, 256, 7, 7 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : ADAPTIVE_POOL(AVG, kernel_size = (2, 2), stride = (1 ,1), padding = (0 ,0)) --> (4, 256, 6, 6)
# Input - ( 4, 256, 7, 7 )
# Output - ( 4, 256, 6, 6 )
# Kernel Size - ( 2, 2 )
# Stride - ( 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 9216) --> (4, 4096, 1, 1)
# Input - ( 4, 9216, 1, 1 )
# Output - ( 4, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 4096, 1, 1)
# Input - ( 4, 4096, 1, 1 )
# Output - ( 4, 4096, 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 4096) --> (4, 4096, 1, 1)
# Input - ( 4, 4096, 1, 1 )
# Output - ( 4, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 4096, 1, 1)
# Input - ( 4, 4096, 1, 1 )
# Output - ( 4, 4096, 1, 1 )
# Processing the Layer Type : LINEAR(out_nodes = 1000, in_nodes = 4096) --> (4, 1000, 1, 1)
# Input - ( 4, 4096, 1, 1 )
# Output - ( 4, 1000, 1, 1 )
# ../forward/data/MiniImageNet/ImageLists.txt
# Running for Batchsize - 8
# Processing the Layer Type : CONV(64, 3, kernel_size = (11, 11), stride = (4 ,4), padding = (2 ,2)) --> (8, 64, 63, 63)
# USING FFT CONVOLUTION
# Input - ( 8, 3, 256, 256 )
# Output - ( 8, 64, 63, 63 )
# TIME ELAPSED - 111.606 = 29.2444 + 5.43014
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 64, 63, 63)
# Input - ( 8, 64, 63, 63 )
# Output - ( 8, 64, 63, 63 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (8, 64, 31, 31)
# Input - ( 8, 64, 63, 63 )
# Output - ( 8, 64, 31, 31 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(192, 64, kernel_size = (5, 5), stride = (1 ,1), padding = (2 ,2)) --> (8, 192, 31, 31)
# USING FFT CONVOLUTION
# Input - ( 8, 64, 31, 31 )
# Output - ( 8, 192, 31, 31 )
# TIME ELAPSED - 150.774 = 38.6247 + 5.18755
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 192, 31, 31)
# Input - ( 8, 192, 31, 31 )
# Output - ( 8, 192, 31, 31 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (8, 192, 15, 15)
# Input - ( 8, 192, 31, 31 )
# Output - ( 8, 192, 15, 15 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(384, 192, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 384, 15, 15)
# USING FFT CONVOLUTION
# Input - ( 8, 192, 15, 15 )
# Output - ( 8, 384, 15, 15 )
# TIME ELAPSED - 405.284 = 238.343 + 5.436
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 384, 15, 15)
# Input - ( 8, 384, 15, 15 )
# Output - ( 8, 384, 15, 15 )
# Processing the Layer Type : CONV(256, 384, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 256, 15, 15)
# USING FFT CONVOLUTION
# Input - ( 8, 384, 15, 15 )
# Output - ( 8, 256, 15, 15 )
# TIME ELAPSED - 531.93 = 309.071 + 6.77354
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 256, 15, 15)
# Input - ( 8, 256, 15, 15 )
# Output - ( 8, 256, 15, 15 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 256, 15, 15)
# USING FFT CONVOLUTION
# Input - ( 8, 256, 15, 15 )
# Output - ( 8, 256, 15, 15 )
# TIME ELAPSED - 407.882 = 224.807 + 4.84294
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 256, 15, 15)
# Input - ( 8, 256, 15, 15 )
# Output - ( 8, 256, 15, 15 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (8, 256, 7, 7)
# Input - ( 8, 256, 15, 15 )
# Output - ( 8, 256, 7, 7 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : ADAPTIVE_POOL(AVG, kernel_size = (2, 2), stride = (1 ,1), padding = (0 ,0)) --> (8, 256, 6, 6)
# Input - ( 8, 256, 7, 7 )
# Output - ( 8, 256, 6, 6 )
# Kernel Size - ( 2, 2 )
# Stride - ( 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 9216) --> (8, 4096, 1, 1)
# Input - ( 8, 9216, 1, 1 )
# Output - ( 8, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 4096, 1, 1)
# Input - ( 8, 4096, 1, 1 )
# Output - ( 8, 4096, 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 4096) --> (8, 4096, 1, 1)
# Input - ( 8, 4096, 1, 1 )
# Output - ( 8, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 4096, 1, 1)
# Input - ( 8, 4096, 1, 1 )
# Output - ( 8, 4096, 1, 1 )
# Processing the Layer Type : LINEAR(out_nodes = 1000, in_nodes = 4096) --> (8, 1000, 1, 1)
# Input - ( 8, 4096, 1, 1 )
# Output - ( 8, 1000, 1, 1 )
# ./test "ALEX" "/content/HP3-CNN-Inferencing/pretrained-models/alexnet.pb"
# FOR THE ALGORITHM : CUDNN
# ../forward/data/MiniImageNet/ImageLists.txt
# Running for Batchsize - 1
# Processing the Layer Type : CONV(64, 3, kernel_size = (11, 11), stride = (4 ,4), padding = (2 ,2)) --> (1, 64, 63, 63)
# USING CUDNNN CONVOLUTION
# Workspace size: 5.49601MB
# Input - ( 1, 3, 256, 256 )
# Output - ( 1, 64, 63, 63 )
# TIME ELAPSED - 8.02394
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 64, 63, 63)
# Input - ( 1, 64, 63, 63 )
# Output - ( 1, 64, 63, 63 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (1, 64, 31, 31)
# Input - ( 1, 64, 63, 63 )
# Output - ( 1, 64, 31, 31 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(192, 64, kernel_size = (5, 5), stride = (1 ,1), padding = (2 ,2)) --> (1, 192, 31, 31)
# USING CUDNNN CONVOLUTION
# Workspace size: 5.86548MB
# Input - ( 1, 64, 31, 31 )
# Output - ( 1, 192, 31, 31 )
# TIME ELAPSED - 0.761856
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 192, 31, 31)
# Input - ( 1, 192, 31, 31 )
# Output - ( 1, 192, 31, 31 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (1, 192, 15, 15)
# Input - ( 1, 192, 31, 31 )
# Output - ( 1, 192, 15, 15 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(384, 192, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 384, 15, 15)
# USING CUDNNN CONVOLUTION
# Workspace size: 7.03271MB
# Input - ( 1, 192, 15, 15 )
# Output - ( 1, 384, 15, 15 )
# TIME ELAPSED - 0.889952
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 384, 15, 15)
# Input - ( 1, 384, 15, 15 )
# Output - ( 1, 384, 15, 15 )
# Processing the Layer Type : CONV(256, 384, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 256, 15, 15)
# USING CUDNNN CONVOLUTION
# Workspace size: 9.37598MB
# Input - ( 1, 384, 15, 15 )
# Output - ( 1, 256, 15, 15 )
# TIME ELAPSED - 1.21754
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 256, 15, 15)
# Input - ( 1, 256, 15, 15 )
# Output - ( 1, 256, 15, 15 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (1, 256, 15, 15)
# USING CUDNNN CONVOLUTION
# Workspace size: 6.25098MB
# Input - ( 1, 256, 15, 15 )
# Output - ( 1, 256, 15, 15 )
# TIME ELAPSED - 0.81488
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 256, 15, 15)
# Input - ( 1, 256, 15, 15 )
# Output - ( 1, 256, 15, 15 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (1, 256, 7, 7)
# Input - ( 1, 256, 15, 15 )
# Output - ( 1, 256, 7, 7 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : ADAPTIVE_POOL(AVG, kernel_size = (2, 2), stride = (1 ,1), padding = (0 ,0)) --> (1, 256, 6, 6)
# Input - ( 1, 256, 7, 7 )
# Output - ( 1, 256, 6, 6 )
# Kernel Size - ( 2, 2 )
# Stride - ( 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 9216) --> (1, 4096, 1, 1)
# Input - ( 1, 9216, 1, 1 )
# Output - ( 1, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 4096, 1, 1)
# Input - ( 1, 4096, 1, 1 )
# Output - ( 1, 4096, 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 4096) --> (1, 4096, 1, 1)
# Input - ( 1, 4096, 1, 1 )
# Output - ( 1, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (1, 4096, 1, 1)
# Input - ( 1, 4096, 1, 1 )
# Output - ( 1, 4096, 1, 1 )
# Processing the Layer Type : LINEAR(out_nodes = 1000, in_nodes = 4096) --> (1, 1000, 1, 1)
# Input - ( 1, 4096, 1, 1 )
# Output - ( 1, 1000, 1, 1 )
# ../forward/data/MiniImageNet/ImageLists.txt
# Running for Batchsize - 2
# Processing the Layer Type : CONV(64, 3, kernel_size = (11, 11), stride = (4 ,4), padding = (2 ,2)) --> (2, 64, 63, 63)
# USING CUDNNN CONVOLUTION
# Workspace size: 0.0227165MB
# Input - ( 2, 3, 256, 256 )
# Output - ( 2, 64, 63, 63 )
# TIME ELAPSED - 1.02739
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 64, 63, 63)
# Input - ( 2, 64, 63, 63 )
# Output - ( 2, 64, 63, 63 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (2, 64, 31, 31)
# Input - ( 2, 64, 63, 63 )
# Output - ( 2, 64, 31, 31 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(192, 64, kernel_size = (5, 5), stride = (1 ,1), padding = (2 ,2)) --> (2, 192, 31, 31)
# USING CUDNNN CONVOLUTION
# Workspace size: 11.731MB
# Input - ( 2, 64, 31, 31 )
# Output - ( 2, 192, 31, 31 )
# TIME ELAPSED - 0.975936
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 192, 31, 31)
# Input - ( 2, 192, 31, 31 )
# Output - ( 2, 192, 31, 31 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (2, 192, 15, 15)
# Input - ( 2, 192, 31, 31 )
# Output - ( 2, 192, 15, 15 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(384, 192, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 384, 15, 15)
# USING CUDNNN CONVOLUTION
# Workspace size: 7.03271MB
# Input - ( 2, 192, 15, 15 )
# Output - ( 2, 384, 15, 15 )
# TIME ELAPSED - 0.93952
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 384, 15, 15)
# Input - ( 2, 384, 15, 15 )
# Output - ( 2, 384, 15, 15 )
# Processing the Layer Type : CONV(256, 384, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 256, 15, 15)
# USING CUDNNN CONVOLUTION
# Workspace size: 9.37598MB
# Input - ( 2, 384, 15, 15 )
# Output - ( 2, 256, 15, 15 )
# TIME ELAPSED - 1.24922
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 256, 15, 15)
# Input - ( 2, 256, 15, 15 )
# Output - ( 2, 256, 15, 15 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (2, 256, 15, 15)
# USING CUDNNN CONVOLUTION
# Workspace size: 6.25098MB
# Input - ( 2, 256, 15, 15 )
# Output - ( 2, 256, 15, 15 )
# TIME ELAPSED - 0.923488
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 256, 15, 15)
# Input - ( 2, 256, 15, 15 )
# Output - ( 2, 256, 15, 15 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (2, 256, 7, 7)
# Input - ( 2, 256, 15, 15 )
# Output - ( 2, 256, 7, 7 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : ADAPTIVE_POOL(AVG, kernel_size = (2, 2), stride = (1 ,1), padding = (0 ,0)) --> (2, 256, 6, 6)
# Input - ( 2, 256, 7, 7 )
# Output - ( 2, 256, 6, 6 )
# Kernel Size - ( 2, 2 )
# Stride - ( 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 9216) --> (2, 4096, 1, 1)
# Input - ( 2, 9216, 1, 1 )
# Output - ( 2, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 4096, 1, 1)
# Input - ( 2, 4096, 1, 1 )
# Output - ( 2, 4096, 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 4096) --> (2, 4096, 1, 1)
# Input - ( 2, 4096, 1, 1 )
# Output - ( 2, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (2, 4096, 1, 1)
# Input - ( 2, 4096, 1, 1 )
# Output - ( 2, 4096, 1, 1 )
# Processing the Layer Type : LINEAR(out_nodes = 1000, in_nodes = 4096) --> (2, 1000, 1, 1)
# Input - ( 2, 4096, 1, 1 )
# Output - ( 2, 1000, 1, 1 )
# ../forward/data/MiniImageNet/ImageLists.txt
# Running for Batchsize - 4
# Processing the Layer Type : CONV(64, 3, kernel_size = (11, 11), stride = (4 ,4), padding = (2 ,2)) --> (4, 64, 63, 63)
# USING CUDNNN CONVOLUTION
# Workspace size: 0.0227165MB
# Input - ( 4, 3, 256, 256 )
# Output - ( 4, 64, 63, 63 )
# TIME ELAPSED - 1.31629
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 64, 63, 63)
# Input - ( 4, 64, 63, 63 )
# Output - ( 4, 64, 63, 63 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (4, 64, 31, 31)
# Input - ( 4, 64, 63, 63 )
# Output - ( 4, 64, 31, 31 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(192, 64, kernel_size = (5, 5), stride = (1 ,1), padding = (2 ,2)) --> (4, 192, 31, 31)
# USING CUDNNN CONVOLUTION
# Workspace size: 0.00550461MB
# Input - ( 4, 64, 31, 31 )
# Output - ( 4, 192, 31, 31 )
# TIME ELAPSED - 1.26291
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 192, 31, 31)
# Input - ( 4, 192, 31, 31 )
# Output - ( 4, 192, 31, 31 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (4, 192, 15, 15)
# Input - ( 4, 192, 31, 31 )
# Output - ( 4, 192, 15, 15 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(384, 192, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 384, 15, 15)
# USING CUDNNN CONVOLUTION
# Workspace size: 7.03271MB
# Input - ( 4, 192, 15, 15 )
# Output - ( 4, 384, 15, 15 )
# TIME ELAPSED - 1.1927
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 384, 15, 15)
# Input - ( 4, 384, 15, 15 )
# Output - ( 4, 384, 15, 15 )
# Processing the Layer Type : CONV(256, 384, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 256, 15, 15)
# USING CUDNNN CONVOLUTION
# Workspace size: 9.37598MB
# Input - ( 4, 384, 15, 15 )
# Output - ( 4, 256, 15, 15 )
# TIME ELAPSED - 1.64621
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 256, 15, 15)
# Input - ( 4, 256, 15, 15 )
# Output - ( 4, 256, 15, 15 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (4, 256, 15, 15)
# USING CUDNNN CONVOLUTION
# Workspace size: 6.25098MB
# Input - ( 4, 256, 15, 15 )
# Output - ( 4, 256, 15, 15 )
# TIME ELAPSED - 1.16611
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 256, 15, 15)
# Input - ( 4, 256, 15, 15 )
# Output - ( 4, 256, 15, 15 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (4, 256, 7, 7)
# Input - ( 4, 256, 15, 15 )
# Output - ( 4, 256, 7, 7 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : ADAPTIVE_POOL(AVG, kernel_size = (2, 2), stride = (1 ,1), padding = (0 ,0)) --> (4, 256, 6, 6)
# Input - ( 4, 256, 7, 7 )
# Output - ( 4, 256, 6, 6 )
# Kernel Size - ( 2, 2 )
# Stride - ( 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 9216) --> (4, 4096, 1, 1)
# Input - ( 4, 9216, 1, 1 )
# Output - ( 4, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 4096, 1, 1)
# Input - ( 4, 4096, 1, 1 )
# Output - ( 4, 4096, 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 4096) --> (4, 4096, 1, 1)
# Input - ( 4, 4096, 1, 1 )
# Output - ( 4, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (4, 4096, 1, 1)
# Input - ( 4, 4096, 1, 1 )
# Output - ( 4, 4096, 1, 1 )
# Processing the Layer Type : LINEAR(out_nodes = 1000, in_nodes = 4096) --> (4, 1000, 1, 1)
# Input - ( 4, 4096, 1, 1 )
# Output - ( 4, 1000, 1, 1 )
# ../forward/data/MiniImageNet/ImageLists.txt
# Running for Batchsize - 8
# Processing the Layer Type : CONV(64, 3, kernel_size = (11, 11), stride = (4 ,4), padding = (2 ,2)) --> (8, 64, 63, 63)
# USING CUDNNN CONVOLUTION
# Workspace size: 0.0227165MB
# Input - ( 8, 3, 256, 256 )
# Output - ( 8, 64, 63, 63 )
# TIME ELAPSED - 2.11978
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 64, 63, 63)
# Input - ( 8, 64, 63, 63 )
# Output - ( 8, 64, 63, 63 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (8, 64, 31, 31)
# Input - ( 8, 64, 63, 63 )
# Output - ( 8, 64, 31, 31 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(192, 64, kernel_size = (5, 5), stride = (1 ,1), padding = (2 ,2)) --> (8, 192, 31, 31)
# USING CUDNNN CONVOLUTION
# Workspace size: 0.00550461MB
# Input - ( 8, 64, 31, 31 )
# Output - ( 8, 192, 31, 31 )
# TIME ELAPSED - 1.984
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 192, 31, 31)
# Input - ( 8, 192, 31, 31 )
# Output - ( 8, 192, 31, 31 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (8, 192, 15, 15)
# Input - ( 8, 192, 31, 31 )
# Output - ( 8, 192, 15, 15 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : CONV(384, 192, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 384, 15, 15)
# USING CUDNNN CONVOLUTION
# Workspace size: 7.03271MB
# Input - ( 8, 192, 15, 15 )
# Output - ( 8, 384, 15, 15 )
# TIME ELAPSED - 1.57514
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 384, 15, 15)
# Input - ( 8, 384, 15, 15 )
# Output - ( 8, 384, 15, 15 )
# Processing the Layer Type : CONV(256, 384, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 256, 15, 15)
# USING CUDNNN CONVOLUTION
# Workspace size: 9.37598MB
# Input - ( 8, 384, 15, 15 )
# Output - ( 8, 256, 15, 15 )
# TIME ELAPSED - 2.13034
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 256, 15, 15)
# Input - ( 8, 256, 15, 15 )
# Output - ( 8, 256, 15, 15 )
# Processing the Layer Type : CONV(256, 256, kernel_size = (3, 3), stride = (1 ,1), padding = (1 ,1)) --> (8, 256, 15, 15)
# USING CUDNNN CONVOLUTION
# Workspace size: 6.25098MB
# Input - ( 8, 256, 15, 15 )
# Output - ( 8, 256, 15, 15 )
# TIME ELAPSED - 1.48256
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 256, 15, 15)
# Input - ( 8, 256, 15, 15 )
# Output - ( 8, 256, 15, 15 )
# Processing the Layer Type : POOL(MAX, kernel_size = (3, 3), stride = (2 ,2), padding = (0 ,0)) --> (8, 256, 7, 7)
# Input - ( 8, 256, 15, 15 )
# Output - ( 8, 256, 7, 7 )
# Kernel Size - ( 3, 3 )
# Stride - ( 2, 2 )
# Processing the Layer Type : ADAPTIVE_POOL(AVG, kernel_size = (2, 2), stride = (1 ,1), padding = (0 ,0)) --> (8, 256, 6, 6)
# Input - ( 8, 256, 7, 7 )
# Output - ( 8, 256, 6, 6 )
# Kernel Size - ( 2, 2 )
# Stride - ( 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 9216) --> (8, 4096, 1, 1)
# Input - ( 8, 9216, 1, 1 )
# Output - ( 8, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 4096, 1, 1)
# Input - ( 8, 4096, 1, 1 )
# Output - ( 8, 4096, 1, 1 )
# Processing the Layer Type : DROPUT
# Processing the Layer Type : LINEAR(out_nodes = 4096, in_nodes = 4096) --> (8, 4096, 1, 1)
# Input - ( 8, 4096, 1, 1 )
# Output - ( 8, 4096, 1, 1 )
# Processing the Layer Type : ACTIVATION(RELU) --> (8, 4096, 1, 1)
# Input - ( 8, 4096, 1, 1 )
# Output - ( 8, 4096, 1, 1 )
# Processing the Layer Type : LINEAR(out_nodes = 1000, in_nodes = 4096) --> (8, 1000, 1, 1)
# Input - ( 8, 4096, 1, 1 )
# Output - ( 8, 1000, 1, 1 )
